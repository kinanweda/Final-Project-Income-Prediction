# %% [markdown]
# # **Income Prediction**
#
# Dalam notebook ini, Saya akan membuat machine yang bisa memprediksi income seseorang apakah orang tersebut mempunyai income lebih dari 50.0000 dolar dalam satu tahun. Data yang saya ambil berasal dari UCI Machine Learning yang dipublis di [Kaggle.com](https://www.kaggle.com/uciml/adult-census-income). Tujuan dari project ini adalah saya menyadari bahwa pentingnya mengetahui besaran income dalam suatu wilayah untuk memulai suatu bisnis supaya bisa mengetahui target pasar yang pas, dan bisa estimasi nilai harga dari produk yang akan kita jual. Selain untuk mengetahui dari segi income, kita juga bisa mengetahui pekerjaan mayoritas penduduk di suatu wilayah tersebut.
#
# Sebelum memulai untuk membuat project ini, saya akan mnedeskripsikan data yang terdapat dalam datasets tersebut :
#
# **Data Set Characteristics:**
#
# * Jumlah data (rows): 32561
#
# * Jumlah Feature (columns): 15 categorical, numeric.
#
# * Daftar Feature:
#     - **age** : menjelaskan umur dari narasumber yang diambil
#     - **workclass** : kelas tempat narasumber bekerja
#     - **finalweight** : bobot yang diciptakan oleh Current Population Survey (CPS) dikontrol untuk memperkirakan independen populasi sipil non-institusional AS
#     - **education** : menjelaskan pendidikan terakhir narasumber
#     - **educationNumber** : labeling pendidikan dalam bentuk numerical
#     - **maritalStatus** : menjelaskan status pernikahan narasumber
#     - **occupation** : menjelaskan pekerjaan narasumber saat ini
#     - **relationship** : menjelaskan status hubungan narasumber saat ini
#     - **race** : ras narasumber dalam suatu wilayah mereka tinggal
#     - **sex** : menjelaskan narasumber tersebut pria atau wanita
#     - **capitalGain** : menjelaskan apakah narasumber ikut dalam penanaman modal dan berapa keuntungan yang didapat
#     - **capitalLoss** : menjelaskan apakah narasumber ikut dalam penanaman modal dan berapa kerugian yang didapat
#     - **hoursperweek** : menjelaskan berapa jam mereka bekerja dalam satu minggu
#     - **nativeCountry** : menjelaskan di negara mana dia berasal
#     - **income** : merupakan target yang akan di predict berisi apakah income seseorang >50.000 atau tidak.
#
#
# * Informasi Categorical Feature :
#     - **workclass** : dalam fitur ini kategori yang tercatat dalam datasets :
#         - **?** : Tidak diketahui dimana narasumber bekerja
#         - **Federal-gov** : Narasumber bekerja pemerintahan federal
#         - **Local-gov** : Narasumber bekerja di pemerintahan lokal biasanya dalam suatu wilayah (kota atau desa)
#         - **Never-worked** : Narasumber belum pernah bekerja
#         - **Private** : Narasumber bekerja sebagai karyawan di perusahaan swasta
#         - **Self-emp-inc** : Narasumber sebagai wiraswasta atau membuat bisnis sendiri dalam entitas perusahaan
#         - **Self-emp-not-inc** : Narasumbernarasumber sebagai wiraswasta atau membuat bisnis sendiri dalam entitas lainnya yang sah
#         - **State-gov** : Narasumber bekerja pemerintahan serikat
#         - **Without-pay** : Narasumber yang bekerja tanpa dibayar tetapi masih memiliki penghasilan entah dari pekerjaan kedua atau pekerjaan sebelumnya
#     - **education** : dalam fitur ini kategori yang tercatat dalam datasets :
#         - **Preschool** : Narasumber yang tidak pernah sekolah
#         - **1st-4th** : Narasumber yang menyelesaikan sekolah antara kelas 1 sampai kelas 4
#         - **5th-6th** : Narasumber yang menyelesaikan sekolah antara kelas 5 sampai kelas 6
#         - **7th-8th** : Narasumber yang menyelesaikan sekolah antara kelas 7 sampai kelas 8
#         - **9th** : Narasumber yang pendidikan terakhirnya lulus SMP
#         - **10th** : Narasumber yang menyelesaikan sekolah pada kelas 10
#         - **11th** : Narasumber yang menyelesaikan sekolah pada kelas 11
#         - **12th** : Narasumber yang menyelesaikan sekolah pada kelas 12
#         - **HS-grad** : Narasumber yang pendidikan terakhirnya lulus SMA
#         - **Some-college** : Narasumber yang berhenti kuliah tetapi masih bisa dilanjutkan kemudian hari
#         - **Assoc-voc** : Narasumber yang telah lulus vokasi
#         - **Assoc-acdm** : Hampir sama dengan lulus vokasi
#         - **Bachelors** : Narasumber yang telah mencapai gelar sarjana
#         - **Masters** : Narasumber yang telah mencapai gelar master
#         - **Prof-school** : Narasumber yang lulus dalam prefessional school
#         - **Doctorate** :Narasumber yang telah mencapai gelar doctor
#     - **maritalStatus** : Dalam fitur ini kategori yang tercatat dalam datasets :
#         - **Never-married** : Belum pernah menikah
#         - **Married-civ-spouse** : Menikah dengan warga sipil
#         - **Divorced** : Cerai
#         - **Married-spouse-absent** : Menikah tetapi pasangan terdapat panggilan tugas (Militer)
#         - **Separated** : Menikah dan memutuskan untuk tidak tinggal bersama
#         - **Married-AF-spouse** : Menikah dengan warga yang bekerja militer
#         - **Widowed** : Pernah menikah
#     - **occupation** : dalam fitur ini kategori yang tercatat dalam datasets :
#         - **Adm-clerical** : Bekerja sebagai administrasi
#         - **Exec-managerial** : Bekerja sebagai executive managerial
#         - **Handlers-cleaners** : Tukang bersih-bersih
#         - **Prof-specialty** : Spesialis professional
#         - **Other-service** : Jasa lainnya
#         - **Sales** : Penjual atau sales
#         - **Craft-repair** : Pengrajin
#         - **Transport-moving** : Transportas bergerak
#         - **Farming-fishing** : Nelayan atau Petani
#         - **Machine-op-inspct** : Inspeksi mesin operator
#         - **Tech-support** : Teknikal Support
#         - **?** : Undefined
#         - **Protective-serv** : Jasa keamanan
#         - **Armed-Forces** : Tentara
#         - **Priv-house-serv** : Pembantu Rumah Tangga
#     - **relationship** : Dalam fitur ini kategori yang tercatat dalam datasets :
#         - **Not-in-family** : tidak berkeluarga
#         - **Husband** : Suami
#         - **Wife** : Istri
#         - **Own-child** : Mempunyai anak
#         - **Unmarried** : Belum Menikah
#         - **Other-relative** : Lainnya
#     - **race** : Dalam fitur ini kategori yang tercatat dalam datasets :
#         - White
#         - Black
#         - Asian-Pac-Islander
#         - Amer-Indian-Eskimo
#         - Other
#
# * Missing Attribute Values:
#     1. workclass = 1836
#     2. occupation = 1843
#     3. nativeCountry = 583
#
#
# * Class Distribution: 24720 - '<=50K', 7841 - '>50K
#
# Saat mengatasi masalah ini, saya mengikuti kerangka kerja yang saya gunakan untuk menyerang semua masalah pembelajaran mesin saya. Ini termasuk langkah-langkah berikut :
#
#    1. Import Libraries and Data
#    2. Exploratory Data Analysis (EDA)
#    3. Dealing with Missing Data
#    4. Evaluate Model
#    5. Finalizing and Optimizing Model
#    6. Conclusion and Business Orientation
#
# Saya harap Anda menikmati notebook ini dan merasa bermanfaat. Harap diingat bahwa ini adalah Notebook pertama saya di sini jadi beri masukan supaya kita bisa berkembang bersama!

# %% [markdown]
# ## 1. Import Libraries and Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('income_evaluation.csv')
df.head()
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country  income
# 0           2174              0               40   United-States   <=50K
# 1              0              0               13   United-States   <=50K
# 2              0              0               40   United-States   <=50K
# 3              0              0               40   United-States   <=50K
# 4              0              0               40            Cuba   <=50K

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age                32561 non-null int64
#  workclass         32561 non-null object
#  fnlwgt            32561 non-null int64
#  education         32561 non-null object
#  education-num     32561 non-null int64
#  marital-status    32561 non-null object
#  occupation        32561 non-null object
#  relationship      32561 non-null object
#  race              32561 non-null object
#  sex               32561 non-null object
#  capital-gain      32561 non-null int64
#  capital-loss      32561 non-null int64
#  hours-per-week    32561 non-null int64
#  native-country    32561 non-null object
#  income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ## 2. EDA

# %% [markdown]
# #### 2.1 Fixing Columns

# %%
df.columns = ['age','workclass','finalweight',
              'education','educationNumber','maritalStatus',
              'occupation','relationship','race',
              'sex','capitalGain','capitalLoss',
              'hoursperweek','nativeCountry','income']
df.head()
# Out:
#    age          workclass  finalweight   education  educationNumber  \
# 0   39          State-gov        77516   Bachelors               13
# 1   50   Self-emp-not-inc        83311   Bachelors               13
# 2   38            Private       215646     HS-grad                9
# 3   53            Private       234721        11th                7
# 4   28            Private       338409   Bachelors               13
#
#          maritalStatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalGain  capitalLoss  hoursperweek   nativeCountry  income
# 0         2174            0            40   United-States   <=50K
# 1            0            0            13   United-States   <=50K
# 2            0            0            40   United-States   <=50K
# 3            0            0            40   United-States   <=50K
# 4            0            0            40            Cuba   <=50K

# %% [markdown]
# #### 2.2 Decribe the Data

# %%
df.describe().T
# Out:
#                    count           mean            std      min       25%  \
# age              32561.0      38.581647      13.640433     17.0      28.0
# finalweight      32561.0  189778.366512  105549.977697  12285.0  117827.0
# educationNumber  32561.0      10.080679       2.572720      1.0       9.0
# capitalGain      32561.0    1077.648844    7385.292085      0.0       0.0
# capitalLoss      32561.0      87.303830     402.960219      0.0       0.0
# hoursperweek     32561.0      40.437456      12.347429      1.0      40.0
#
#                       50%       75%        max
# age                  37.0      48.0       90.0
# finalweight      178356.0  237051.0  1484705.0
# educationNumber      10.0      12.0       16.0
# capitalGain           0.0       0.0    99999.0
# capitalLoss           0.0       0.0     4356.0
# hoursperweek         40.0      45.0       99.0

# %%
listItem = []
for col in df.columns :
    listItem.append([col, df[col].dtype, df[col].isna().sum(), round((df[col].isna().sum()/len(df[col]))*100,2),
                     df[col].nunique(), list(df[col].unique()[:3])])
dfDesc = pd.DataFrame( columns=['dataFeatures','dataType','null','nullPct','unique','uniqueSample'], data=listItem)
dfDesc
# Out:
#        dataFeatures dataType  null  nullPct  unique  \
# 0               age    int64     0      0.0      73
# 1         workclass   object     0      0.0       9
# 2       finalweight    int64     0      0.0   21648
# 3         education   object     0      0.0      16
# 4   educationNumber    int64     0      0.0      16
# 5     maritalStatus   object     0      0.0       7
# 6        occupation   object     0      0.0      15
# 7      relationship   object     0      0.0       6
# 8              race   object     0      0.0       5
# 9               sex   object     0      0.0       2
# 10      capitalGain    int64     0      0.0     119
# 11      capitalLoss    int64     0      0.0      92
# 12     hoursperweek    int64     0      0.0      94
# 13    nativeCountry   object     0      0.0      42
# 14           income   object     0      0.0       2
#
#                                          uniqueSample
# 0                                        [39, 50, 38]
# 1           [ State-gov,  Self-emp-not-inc,  Private]
# 2                              [77516, 83311, 215646]
# 3                       [ Bachelors,  HS-grad,  11th]
# 4                                          [13, 9, 7]
# 5    [ Never-married,  Married-civ-spouse,  Divorced]
# 6   [ Adm-clerical,  Exec-managerial,  Handlers-cl...
# 7                   [ Not-in-family,  Husband,  Wife]
# 8               [ White,  Black,  Asian-Pac-Islander]
# 9                                    [ Male,  Female]
# 10                                   [2174, 0, 14084]
# 11                                    [0, 2042, 1408]
# 12                                       [40, 13, 16]
# 13                  [ United-States,  Cuba,  Jamaica]
# 14                                    [ <=50K,  >50K]

# %% [markdown]
# #### 2.3 Analyze the Target

# %%
df['income'] = df['income'].apply(
    lambda x : 1 if x != ' <=50K' else 0
)

# %%
sns.set_style('whitegrid')
sns.countplot(x='income',data=df,palette='Set1')

# %% [markdown]
# Terlihat data yang tidak seimbang di dalam target yang akan saya predict nanti, untuk income kurang dari 50.000 dolar lebih banyak dibanding income lebih dari 50.000 dolar

# %% [markdown]
# #### 2.4 Analyze Categorical Feature

# %% [markdown]
# Untuk permulaan saya membuat list yang berisi categorical feature

# %%
categorical = [i for i in df.columns.drop(['income','nativeCountry']) if df[i].dtype == 'O']

# %% [markdown]
# Setelah itu saya membuat plot tiap kategori di setiap feature dan melihat korelasi antar kategoroi terhadap income.

# %%
for i in range(len(categorical)) :
    plt.figure(figsize=(60,5))
    plt.subplot(1,7,i+1)
    sns.countplot(x='income', hue=f'{categorical[i]}', data=df, palette='Set1')
    plt.xticks(rotation=90)
plt.show()

# %%
# untuk melihat rasio per kategori dalam feature
df.groupby(['sex'])['income'].mean()
# Out:
# sex
#  Female    0.109461
#  Male      0.305737
# Name: income, dtype: float64

# %%
df.groupby(['income'])['occupation'].value_counts()
# Out:
# income  occupation
# 0        Adm-clerical         3263
#          Craft-repair         3170
#          Other-service        3158
#          Sales                2667
#          Prof-specialty       2281
#          Exec-managerial      2098
#          Machine-op-inspct    1752
#          ?                    1652
#          Handlers-cleaners    1284
#          Transport-moving     1277
#          Farming-fishing       879
#          Tech-support          645
#          Protective-serv       438
#          Priv-house-serv       148
#          Armed-Forces            8
# 1        Exec-managerial      1968
#          Prof-specialty       1859
#          Sales                 983
#          Craft-repair          929
#          Adm-clerical          507
#          Transport-moving      320
#          Tech-support          283
#          Machine-op-inspct     250
#          Protective-serv       211
#          ?                     191
#          Other-service         137
#          Farming-fishing       115
#          Handlers-cleaners      86
#          Armed-Forces            1
#          Priv-house-serv         1
# Name: occupation, dtype: int64

# %%
df[(df['education']==' Doctorate')&(df['income']==0)].count()
# Out:
# age                107
# workclass          107
# finalweight        107
# education          107
# educationNumber    107
# maritalStatus      107
# occupation         107
# relationship       107
# race               107
# sex                107
# capitalGain        107
# capitalLoss        107
# hoursperweek       107
# nativeCountry      107
# income             107
# dtype: int64

# %%
for i in range(len(categorical)) :
    plt.figure(figsize=(60,5))
    plt.subplot(1,7,i+1)
    sns.countplot(x=f'{categorical[i]}', hue='income', data=df)
    plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Terlihat diatas untuk dari plot yang saya buat, terdapat informasi dari tiap kategori, saya akan menjelaskan dibawah :
#
# * Untuk feature workclass :
#    1. Terdapat kategori '?' yang tidak menunjukkan informasi apapun
#    2. Terlihat bahwa mayoritas dalam data tersebut adalah yang bekerja di perusahaan swasta, baik dari income >50K maupun yang <=50K
#    3. Terdapat korelasi antara workclass terhadap income
# * Untuk feature education :
#    1. Tidak terdapatnya ketegori '?'
#    2. Terlihat bahwa banyaknya lulusan SMA daripada lulusan Sarjana dalam data, dan untuk mayoritas lulusan SMA incomenya <=50K. Walopun secara keseluruhan secara education perbandingan antara income yang <=50K dengan yang >50K lebih banyak <=50K, tidak seperti feature occupation yang penghasilan >50K lebih banyak daripada feature esucation, hal ini cukup masuk akal mengingat besarnya income juga dipengaruhi besar oleh sebagai apa mereka bekerja
#    3. Terdapat korelasi antara education terhadap income
# * Untuk feature maritalStatus :
#    1. Tidak terdapatnya ketegori '?'
#    2. Banyaknya warga yang telah menikah dibanding yang belum menikah, tetapi sedikit sekali warga yang belum menikah yang mempunyai income >50K.
#    3. Terdapat korelasi antara maritalStatus terhadap income
# * Untuk feature occupation :
#    1. Terdapat kategori '?' yang tidak menunjukkan informasi apapun
#    2. Terlihat bahwa untuk pekerjaan executive managerial lebih banyak yang incomenya >50K dalam setahun tetapi untuk income <=50K jumlah warga yang bekerja bagian executive managerial juga tidak kalah banyak bahkan hampir mengimbangi. Tetapi untuk spesialis profesional, sangat jauh perbandingan antara income yang >50K daripada yang <=50K dan mayoritas income mereka >50K.
#    3. Terdapat korelasi antara occupation terhadap income
# * Untuk feature relationship :
#    1. Tidak terdapatnya ketegori '?'
#    2. Lebih banyak warga yang sudah menikah, dan terlihat bahwa relationship sebagai suami tidak kalah banyak yang incomenya >50K bahkan diantara kategori relationship lainnya untuk kategori husband paling tinggi jumlahnya yang mempunyai income >50K
# * Untuk feature race :
#    1. Tidak terdapatnya kategori '?'
#    2. Banyaknya jumlah ras White dalam data, untuk kedua kategori dalam fitur income baik lebih ataupun kurang dari 50K ras putih lebih banyak.
#    3. Untuk feature ini kurang berkorelasi terhadap income, karena pola yang terlihat sama
# * Untuk feature sex :
#    1. Tidak terdapatnya kategori '?'
#    2. Untuk feature ini kurang berkorelasi terhadap income, karena pola yang terlihat sama
#
# Walaupun untuk feature race dan sex terlihat mempunyai korelasi yang rendah terhadap income, saya akan melihat terlebih dahulu bila kedua feature tersebut akan dimasukkan dalam fitting model

# %% [markdown]
# Saya ingin melihat beberapa kategori yang menurut saya unik untuk dianalisa lebih lanjut supaya saya semakin jelas melihat pola data yang ada

# %% [markdown]
# #### 2.4.1 Fixing Name of Feature and Data

# %%
categorical = [i for i in df.columns.drop(['income']) if df[i].dtype == 'O']
for i in categorical:
    df[i] = [col.replace(' ','') for col in df[i].values]

# %% [markdown]
# #### 2.4.2 Analyze Categorical Feature

# %% [markdown]
# ##### 2.4.1.1 Occupation

# %% [markdown]
# Dari plot diatas data menunjukkan bahwa untuk untuk berpenghasilan >50K, tidak harus terpaku terhadap tingginya pendidikan yang mereka tempuh, tetapi tergantung juga dari jenis pekerjaan yang mereka jalani. Saya tertarik untuk menganalisa feature occupation, selain feature ini juga mempengaruhi tinggi rendahnya suatu income, terdapat pula satu kategori yang unik "?" di dalam feature tersebut.

# %%
df['occupation'].value_counts()
# Out:
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
display(df[df['occupation']== '?'].head())
print(df[df['occupation']== '?'].shape)
# Out:
#      age workclass  finalweight     education  educationNumber  \
# 27    54         ?       180211  Some-college               10
# 61    32         ?       293936       7th-8th                4
# 69    25         ?       200681  Some-college               10
# 77    67         ?       212759          10th                6
# 106   17         ?       304873          10th                6
#
#              maritalStatus occupation   relationship                race  \
# 27      Married-civ-spouse          ?        Husband  Asian-Pac-Islander
# 61   Married-spouse-absent          ?  Not-in-family               White
# 69           Never-married          ?      Own-child               White
# 77      Married-civ-spouse          ?        Husband               White
# 106          Never-married          ?      Own-child               White
#
#         sex  capitalGain  capitalLoss  hoursperweek  nativeCountry  income
# 27     Male            0            0            60          South       1
# 61     Male            0            0            40              ?       0
# 69     Male            0            0            40  United-States       0
# 77     Male            0            0             2  United-States       0
# 106  Female        34095            0            32  United-States       0
# (1843, 15)

# %% [markdown]
# dari dataframe diatas, asumsi saya setiap workclass yang berisi '?' maka occupationnya juga mengikuti '?', untuk membuktikannya mari kita lihat dataframe dibawah

# %%
df[(df['occupation']=='?')&(df['workclass']!='?')]['workclass']
# untuk occupation ? dan workclass ? dihapus
# untuk occupation ? dan workclass Never-worked, ? diganti None
# Out:
# 5361     Never-worked
# 10845    Never-worked
# 14772    Never-worked
# 20337    Never-worked
# 23232    Never-worked
# 32304    Never-worked
# 32314    Never-worked
# Name: workclass, dtype: object

# %% [markdown]
# Ternyata asumsi saya salah, masih terdapat occupation yang tidak jelas dengan yang sejajar dengan kategori Never-worked	pada feature workclass. Hal ini cukup masuk akal karena ketika seseorang belum pernah bekerja maka dia tidak bisa mengisi feature occupation tersebut.

# %% [markdown]
# Karena terdapat dua kondisi di dalam kategori '?' maka, untuk kondisi pertama maka saya akan mengganti '?' menjadi data yang sering muncul di dalam feature ini (modus), tapi sebelum itu saya akan menganalisa lebih lanjut apakah bisa modus di dalam feature ini bisa untuk menggantikan kategori '?'. Untuk itu saya ingin membandingkan pola bila dilihat dari segi income sebagai target dari occupation yang '?' dengan modus dari occupation.

# %%
sns.countplot(df[df['occupation']=='?']['occupation'],hue=df['income'])

# %%
sns.countplot(df[df['occupation']=='Prof-specialty']['occupation'],hue=df['income'])

# %% [markdown]
# Ternyata dari plot diatas menjelaskan bahwa income seorang Prof-speciality cukup seimbang antara yang <=50K dengan yang >50K, tetapi untuk kategori dengan occupation '?' terlihat bahwa untuk income yang >50K lebih sedikit dari <=50K maka dari itu saya tidak akan mengubah occupation '?' menjadi modus dari occupation itu sendiri. Hal ini dikarenakan akan mengubah pola dari target itu sendiri. Dari pola di dalam dataframe diatas bahwa ada dua kemungkinan (asumsi) seseorang tidak mengisi feature occupation, yaitu karena mereka tidak mau menyebutkan mereka bekerja dimana (akan berdampak pada feature workclass yang juga diisi dengan '?') dan ketika seseorang belum pernah bekerja. Untuk itu, saya akan drop seseorang yang occupation dan workclass diisi dengan '?' secara bersamaan karena tidak ada feature lain yang bisa menjelaskan apakah yang bisa menggantikan kategori '?' tersebut dan bila diganti juga akan mengubah target nya (income), tetapi saya akan membiarkan occupation dengan kategori '?' bila workclass diisi dengan 'Never-worked' dan mengganti '?' dengan 'None'. Untuk permulaan saya akan mengganti '?' dengan None.

# %%
df[df['workclass']=='Never-worked']
# Out:
#        age     workclass  finalweight     education  educationNumber  \
# 5361    18  Never-worked       206359          10th                6
# 10845   23  Never-worked       188535       7th-8th                4
# 14772   17  Never-worked       237272          10th                6
# 20337   18  Never-worked       157131          11th                7
# 23232   20  Never-worked       462294  Some-college               10
# 32304   30  Never-worked       176673       HS-grad                9
# 32314   18  Never-worked       153663  Some-college               10
#
#             maritalStatus occupation   relationship   race     sex  \
# 5361        Never-married          ?      Own-child  White    Male
# 10845            Divorced          ?  Not-in-family  White    Male
# 14772       Never-married          ?      Own-child  White    Male
# 20337       Never-married          ?      Own-child  White  Female
# 23232       Never-married          ?      Own-child  Black    Male
# 32304  Married-civ-spouse          ?           Wife  Black  Female
# 32314       Never-married          ?      Own-child  White    Male
#
#        capitalGain  capitalLoss  hoursperweek  nativeCountry  income
# 5361             0            0            40  United-States       0
# 10845            0            0            35  United-States       0
# 14772            0            0            30  United-States       0
# 20337            0            0            10  United-States       0
# 23232            0            0            40  United-States       0
# 32304            0            0            40  United-States       0
# 32314            0            0             4  United-States       0

# %%
plt.subplots(figsize=(12, 8))
sns.countplot(x="occupation", data=df, palette="Set1")
plt.title("Frequency distribution of occupation variable")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Memang Prof-Specialty dan Exec-Managerial diatas terlihat mempunyai jumlah yang cukup besar, untuk selanjutnya saya ingin melihat status education terakhir khusus untuk penduduk yang bekerja di Prof-specialty dan Exec-managerial yang dimiliki. Apakah orang yang dibawah lulusan S1 bisa bekerja dibidang Prof-specialty dan Exec-Managerial

# %%
plt.figure(figsize=(15,20))
plt.subplot(2,1,1)
sns.countplot(df[(df['occupation']=='Prof-specialty')]['education'],hue=df['income'])
plt.xticks(rotation=90)
plt.title('Prof-specialty')
plt.subplot(2,1,2)
sns.countplot(df[(df['occupation']=='Exec-managerial')]['education'],hue=df['income'])
plt.title('Exec-Managerial')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Terlihat diatas untuk dari plot yang saya buat, terdapat informasi dari tiap kategori, saya akan menjelaskan dibawah :
#
# * Untuk jenis pekerjaan Prof-specialty :
#    1. Terbukti bahwa didalam pekerjaan Prof-specialty terdapat lulusan dibawah S-1, dan terdapat pula yang meiliki income >50K
#    2. Bahkan ada pula yang tidak tamat SMA yang bekerja di bidang Prof-specialty dan mendapatkan income >50K
# * Untuk jenis pekerjaan Exec-managerial :
#    1. Terbukti juga bahwa didalam pekerjaan Exec-managerial terdapat lulusan dibawah S-1, dan terdapat pula yang meiliki income >50K
#    2. Bahkan yang cukup menarik terdapat penduduk yang tidak tamat bangku SD bekerja di Exec-managerial dengan income >50K

# %% [markdown]
# Saya juga ingin tahu bahwa untuk lulusan SMA, paling banyak bekerja sebagai apa

# %%
plt.figure(figsize=(8,8))
sns.countplot(x=df[(df['income']==1)&(df['education']=='HS-grad')]['occupation'],palette='Set1')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(x=df[df['education']=='HS-grad']['occupation'], hue=df['income'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.countplot(x=df[(df['income']==1)&(df['maritalStatus']=='Married-civ-spouse')]['occupation'],palette='Set1',hue=df['sex'])
plt.xticks(rotation=90)
plt.xlabel('Married-civ-spouse with income >50K')
plt.subplot(1,2,2)
sns.countplot(x=df[(df['income']==0)&(df['maritalStatus']=='Married-civ-spouse')]['occupation'],palette='Set1',hue=df['sex'])
plt.xticks(rotation=90)
plt.xlabel('Married-civ-spouse with income <=50K')
plt.show()

# %% [markdown]
# ##### 2.4.1.2 Native Country

# %%
df['nativeCountry'].value_counts()
# Out:
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# Greece                           29
# France                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Trinadad&Tobago                  19
# Cambodia                         19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: nativeCountry, dtype: int64

# %%
f, ax = plt.subplots(figsize=(16, 12))
ax = sns.countplot(x="nativeCountry", data=df, palette="Set1")
ax.set_title("Frequency distribution of native_country variable")
ax.set_xticklabels(df.nativeCountry.value_counts().index, rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot('nativeCountry',hue='income',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
for item,i in enumerate(categorical):
    if i != 'nativeCountry':
        plt.figure(figsize=(15,8))
        plt.subplot(1,2,1)
        x=sns.countplot(df[(df['income']==1)&(df['nativeCountry']=='United-States')]['nativeCountry'],hue=df[i],palette='Set1')
        for p in x.patches:
            x.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
        plt.title('Income >50K')
        plt.subplot(1,2,2)
        x=sns.countplot(df[(df['income']==0)&(df['nativeCountry']=='United-States')]['nativeCountry'],hue=df[i],palette='Set1')
        for p in x.patches:
            x.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
        plt.title('Income <=50K')
    else:
        continue

# %% [markdown]
# Terlihat diatas untuk dari plot yang saya buat, terdapat informasi dari tiap kategori, saya akan menjelaskan dibawah :
#
# * Untuk feature workclass :
#    1. Terlihat bahwa self-emp-inc lebih banyak income >50K daripada income <=50K
#    2. Di United-States, dilihat dari perbandingan kesempatan tertinggi untuk mendapatkan income >50K yaitu bekerja dibawah local government (lebih dari 35% dari total seluruh workclass kategori local-government)
# * Untuk feature education :
#    1. Terlihat bahwa lulusan Masters keatas di United-States mayoritas memiliki income >50K per tahun
#    2. Cukup banyak juga untuk lulusan Bachelor yang mendapatkan income >50K, dan bila dibandingkan dengan income <=50K hampir 42% dari total seluruh lulusan Bachelor, bisa di asumsikan bahwa hal tersebut bisa dipengaruhi oleh lulusan mana dia bekerja
# * Untuk feature maritalStatus :
#    1. Sedikit penduduk yang single (berpisah, belum pernah menikah) di United-States memiliki income >50K, dibanding orang yang telah menikah
#    2. Bahkan lebih dari 40% dari total orang yang telah menikah memiliki income >50K
# * Untuk feature occupation :
#    1. Untuk kategori Exec-managerial dan Prof-specialty memiliki perbandingan lebih dari 40% untuk mendapatkan income >50K
#    2. Walaupun jumlah penduduk yang bekerja sebagai nelayan dan tukang bersih-bersih tetapi terdapat pula yang income nya >50K
#    3. Bahkan 1 orang pembantu rumah tangga mempunyai income >50K dalam 1 tahun
# * Untuk feature relationship :
#    1. Wife dengan income >50K dengan wife yang memiliki income <=50K mempunyai selisih sedikit
#    2. Jumlah suami di Amerika yang memiliki income >50K juga cukup banyak, bahkan bila dibanding dengan kategori yang lain kebanyakan suami memiliki income >50K per tahun

# %% [markdown]
# ##### 2.4.1.3 Workclass

# %% [markdown]
# Sama seperti feature occupation, jenis perusahaan dimana mereka bekerja pun juga bisa mempengaruhi berapa income yang akan diterima, untuk itu saya ingin menganalisa lebih lanjut, dan juga terdapat kategori '?' yang mirip seperti di dalam feauture income.

# %%
df['workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %% [markdown]
# Karena asumsi saya ketika menganalisa feature occupation salah, maka saya juga memeriksa pada feature workclass. Apakah terdapat kategori '?' bila kategori dalam occupation tidak '?'

# %%
df[(df['workclass']=='?')&(df['occupation']!='?')]
# Out:
# Empty DataFrame
# Columns: [age, workclass, finalweight, education, educationNumber, maritalStatus, occupation, relationship, race, sex, capitalGain, capitalLoss, hoursperweek, nativeCountry, income]
# Index: []

# %% [markdown]
# Ternyata untuk feature workclas, hasilnya kosong. Hal ini masih terdapat kemungkinan bahwa sesorang tidak mau untuk memberitahukan apa dan bagian apa mereka bekerja.

# %%
sns.countplot(df[df['workclass']=='Private']['workclass'],hue=df['income'])

# %%
print('Seorang Prof-Speacialty yang berada di perusahaan swasta :',len(df[(df['workclass']=='Private')&(df['occupation']=='Prof-specialty')]))
print('Seorang Prof-Speacialty yang tidak berada di perusahaan swasta :',len(df[(df['workclass']!='Private')&(df['occupation']=='Prof-specialty')]))
# Out:
# Seorang Prof-Speacialty yang berada di perusahaan swasta : 2313
# Seorang Prof-Speacialty yang tidak berada di perusahaan swasta : 1827

# %%
f, ax = plt.subplots(figsize=(10, 6))
ax = df['workclass'].value_counts().plot(kind="bar")
ax.set_title("Frequency distribution of workclass variable")
ax.set_xticklabels(df['workclass'].value_counts().index, rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(df[df['workclass'] == 'Private']['maritalStatus'], hue=df['income'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 2.4.1.3 Education

# %%
df[['education','educationNumber']].sort_values(by=['educationNumber']).head()
# Out:
#        education  educationNumber
# 22940  Preschool                1
# 13248  Preschool                1
# 21370  Preschool                1
# 25943  Preschool                1
# 21388  Preschool                1

# %%
df[df['education']=='Preschool']['educationNumber'].head(1)
# Out:
# 224    1
# Name: educationNumber, dtype: int64

# %%
listEdu = list(df['education'].unique())

# %%
listItem = []
for i in listEdu:
    listItem.append([i,np.unique(df[df['education']==i]['educationNumber'])[0]])

# %%
dfEdu = pd.DataFrame(listItem,columns=['education','educationNumber']).sort_values(by=['educationNumber'])
dfEdu = dfEdu.reset_index()
dfEdu.drop('index',axis=1,inplace=True)
dfEdu
# Out:
#        education  educationNumber
# 0      Preschool                1
# 1        1st-4th                2
# 2        5th-6th                3
# 3        7th-8th                4
# 4            9th                5
# 5           10th                6
# 6           11th                7
# 7           12th                8
# 8        HS-grad                9
# 9   Some-college               10
# 10     Assoc-voc               11
# 11    Assoc-acdm               12
# 12     Bachelors               13
# 13       Masters               14
# 14   Prof-school               15
# 15     Doctorate               16

# %% [markdown]
# Karena feature education dengan educationNumber mempunyai korelasi maka saya akan menghapus column education. Supaya tidak terlalu banyak feature (pemborosan)

# %%
df = df.drop('education',axis=1)

# %% [markdown]
# #### 2.4.2 Analyze Numerical Feature

# %%
numerical = [i for i in df.columns.drop(['income','nativeCountry']) if df[i].dtype != 'O']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(), annot=True)

# %%
#correlation rasio - > untuk melihat dari categorical ke continous

# %%
sns.pairplot(pd.concat([df[numerical],df['income']],axis=1),hue="income")
# Out:
# C:\Users\KINAN BAHUWEDA M\AppData\Local\Programs\Python\Python37\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\KINAN BAHUWEDA M\AppData\Local\Programs\Python\Python37\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# ##### 2.4.2.1 Age

# %%
sns.distplot(df[df['income'] == 0]['age'], kde=True, color='darkred', bins=30)
sns.distplot(df[df['income'] == 1]['age'], kde=True, color='blue', bins=30)

# %% [markdown]
# Dari plot diatas terlihat bahwa masih terdapat umur diatas 80 tahun. Untuk itu saya ingin melihat apakah terdapat penduduk usia 90 tahun yang ,masih bekerja

# %%
sns.countplot(df[df['age']==90]['occupation'])
plt.xticks(rotation=90)
plt.show()

print('Total penduduk yang berusia 90 yang masih bekerja :',sum(df[df['age']==90]['occupation'].value_counts()))
# Out:
# Total penduduk yang berusia 90 yang masih bekerja : 43

# %% [markdown]
# Terdapat 43 penduduk yang berusis 90 tahun yang masih bekerja, dan paling banyak masih bekerja dibagian Exec-managerial, uniknya masih terdapat 1 orang yang bekerja di bidak layanan keamanan dan tukang bersih-bersih. Setelah itu saya ingin melihat berapa lama penduduk berusia 90 tahun ketika bekerja

# %%
sns.distplot(df[df['age']==90]['hoursperweek'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Ternyata terdapat pula yang bekerja diatas 70 hours per week, selanjutnya saya ingin melihat pekerjaan apa yang membuat penduduk berusia 70 tahun bekerja selama 80 hours per week

# %%
df[(df['age']==90)&(df['hoursperweek']>70)]
# Out:
#        age workclass  finalweight  educationNumber       maritalStatus  \
# 8806    90   Private        87372               15  Married-civ-spouse
# 15356   90   Private        90523                9             Widowed
#
#              occupation relationship   race   sex  capitalGain  capitalLoss  \
# 8806     Prof-specialty      Husband  White  Male        20051            0
# 15356  Transport-moving    Unmarried  White  Male            0            0
#
#        hoursperweek  nativeCountry  income
# 8806             72  United-States       1
# 15356            99  United-States       0

# %% [markdown]
# ##### 2.4.2.2 Finalweight

# %%
sns.distplot(df[df['income'] == 0]['finalweight'], kde=True, color='darkred', bins=30)
sns.distplot(df[df['income'] == 1]['finalweight'], kde=True, color='blue', bins=30)

# %% [markdown]
# ##### 2.4.2.3 Capital Gain and Capital Loss

# %%
plt.figure(figsize=(8,10))
sns.distplot(df['capitalGain'],kde=False)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(df[(df['capitalGain']>0)]['workclass'],hue=df['income'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Rata-rata orang yang mendapatkan capitalGain memiliki income >50K per tahun.Tetapi untuk income <=50K juga ikut berinvestasi dan mendapatkan capital gain. Untuk penduduk yang bekerja di pemerintahan, sedikit sekali peminat mereka untuk berinvestasi

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
sns.distplot(df[df['capitalLoss'] == 0]['capitalGain'], kde=False, color='darkred', bins=30)
plt.subplot(1,2,2)
sns.distplot(df[df['capitalLoss'] > 0]['capitalGain'], kde=False, color='blue', bins=30)
plt.show()

# %% [markdown]
# ##### 2.4.2.4 Hours per Week

# %%
plt.figure(figsize=(8,10))
sns.distplot(df['hoursperweek'],kde=False)
plt.show()

# %% [markdown]
# Saya melihat kejanggalan dari plot yang terbentuk diatas, karena terdapat sample yang bekerja 99 hours per week, untuk itu akan saya analisa lebih lanjut, saya ingin melihat jenis pekerjaan apa yang membutuhkan jam kerja yang lebih dari 70 hours per week.

# %%
df[df['hoursperweek']>70]['occupation'].value_counts().plot(kind='bar',title='Occupation hours')
# plt.xticks(rotation=90)
# plt.show()

# %% [markdown]
# Berikutnya saya mau melihat berapa gaji dan pekerjaan apa ketika hours per week nya lebih dari 80 jam.

# %%
sns.countplot(df[df['hoursperweek']>80]['occupation'],hue=df['income'])
plt.xticks(rotation=90)
plt.show()
print('Total',df[df['hoursperweek']>80]['occupation'].count())
# Out:
# Total 208

# %% [markdown]
# Ternyata untuk pekerjaan di Exec-managerial terdapat sekitar 27 orang yang bekerja diatas 80 jam walaupun mereka digaji lebih dari 50K ataupun yang kurang dari 50K. Untuk seorang nelayan, memang masuk akal bila mereka membutuhkan waktu yang lebih lama ketika bekerja karena memang menyesuaikan kondisi untuk mendapatkan ikan terbanyak.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
# age                32561 non-null int64
# workclass          32561 non-null object
# finalweight        32561 non-null int64
# educationNumber    32561 non-null int64
# maritalStatus      32561 non-null object
# occupation         32561 non-null object
# relationship       32561 non-null object
# race               32561 non-null object
# sex                32561 non-null object
# capitalGain        32561 non-null int64
# capitalLoss        32561 non-null int64
# hoursperweek       32561 non-null int64
# nativeCountry      32561 non-null object
# income             32561 non-null int64
# dtypes: int64(7), object(7)
# memory usage: 3.5+ MB

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# finalweight        0
# educationNumber    0
# maritalStatus      0
# occupation         0
# relationship       0
# race               0
# sex                0
# capitalGain        0
# capitalLoss        0
# hoursperweek       0
# nativeCountry      0
# income             0
# dtype: int64

# %% [markdown]
# ## 3. Dealing With Missing Data

# %% [markdown]
# Dari EDA diatas bahwa saya akan drop kategori yang occupation '?' dan workclass '?'

# %%
df['occupation'] = df[['occupation','workclass']].apply(lambda x : 'None' if x['occupation'] == '?' and x['workclass']=='Never-worked' else x['occupation'],axis=1)

# %%
listdrop = df[(df['occupation']=='?')&(df['workclass']=='?')].index
df.drop(listdrop,axis=0,inplace=True)

# %%
df[numerical].isnull().sum()
# Out:
# age                0
# finalweight        0
# educationNumber    0
# capitalGain        0
# capitalLoss        0
# hoursperweek       0
# dtype: int64

# %%
df.describe()
# Out:
#                 age   finalweight  educationNumber   capitalGain  \
# count  30725.000000  3.072500e+04     30725.000000  30725.000000
# mean      38.439512  1.898538e+05        10.129699   1105.785094
# std       13.119665  1.054585e+05         2.562702   7497.027762
# min       17.000000  1.376900e+04         1.000000      0.000000
# 25%       28.000000  1.178330e+05         9.000000      0.000000
# 50%       37.000000  1.785170e+05        10.000000      0.000000
# 75%       47.000000  2.373170e+05        13.000000      0.000000
# max       90.000000  1.484705e+06        16.000000  99999.000000
#
#         capitalLoss  hoursperweek        income
# count  30725.000000  30725.000000  30725.000000
# mean      88.889959     40.946461      0.248983
# std      405.613208     11.987385      0.432431
# min        0.000000      1.000000      0.000000
# 25%        0.000000     40.000000      0.000000
# 50%        0.000000     40.000000      0.000000
# 75%        0.000000     45.000000      0.000000
# max     4356.000000     99.000000      1.000000

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# finalweight        0
# educationNumber    0
# maritalStatus      0
# occupation         0
# relationship       0
# race               0
# sex                0
# capitalGain        0
# capitalLoss        0
# hoursperweek       0
# nativeCountry      0
# income             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# finalweight        0
# educationNumber    0
# maritalStatus      0
# occupation         0
# relationship       0
# race               0
# sex                0
# capitalGain        0
# capitalLoss        0
# hoursperweek       0
# nativeCountry      0
# income             0
# dtype: int64

# %%
df.shape
# Out:
# (30725, 14)

# %% [markdown]
# ### Data with 13 Features

# %%
from sklearn.preprocessing import LabelEncoder

# %%
categorical = [i for i in df.columns.drop(['income']) if df[i].dtype == 'O']
print(categorical)
# Out:
# ['workclass', 'maritalStatus', 'occupation', 'relationship', 'race', 'sex', 'nativeCountry']

# %%
lewc = LabelEncoder()
lemar = LabelEncoder()
leoc = LabelEncoder()
lerl = LabelEncoder()
lerc = LabelEncoder()
lesx = LabelEncoder()
lenc = LabelEncoder()

# %%
lewc.fit(df['workclass'])
lemar.fit(df['maritalStatus'])
leoc.fit(df['occupation'])
lerl.fit(df['relationship'])
lerc.fit(df['race'])
lesx.fit(df['sex'])
lenc.fit(df['nativeCountry'])
# Out:
# LabelEncoder()

# %%
with open('lewc.pickle', 'wb') as f:
    pickle.dump(lewc, f)
with open('lemar.pickle', 'wb') as f:
    pickle.dump(lemar, f)
with open('leoc.pickle', 'wb') as f:
    pickle.dump(leoc, f)
with open('lerl.pickle', 'wb') as f:
    pickle.dump(lerl, f)
with open('lerc.pickle', 'wb') as f:
    pickle.dump(lerc, f)
with open('lesx.pickle', 'wb') as f:
    pickle.dump(lesx, f)
with open('lenc.pickle', 'wb') as f:
    pickle.dump(lenc, f)

# %%
df['workclass'] = lewc.transform(df['workclass'])
df['maritalStatus'] = lemar.transform(df['maritalStatus'])
df['occupation'] = leoc.transform(df['occupation'])
df['relationship'] = lerl.transform(df['relationship'])
df['race'] = lerc.transform(df['race'])
df['sex'] = lesx.transform(df['sex'])
df['nativeCountry'] = lenc.transform(df['nativeCountry'])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df[numerical])
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
with open('scaler.pickle', 'wb') as f:
    pickle.dump(scaler, f)

# %%
dfScaled = pd.DataFrame(scaler.transform(df[numerical]),columns=df[numerical].columns)

# %%
dfLabeled = pd.DataFrame(df[categorical],columns=df[categorical].columns)
dfLabeled = dfLabeled.reset_index(drop=True)

# %%
dfScaled = pd.concat([dfLabeled,dfScaled],axis=1)

# %%
dfScaled.head()
# Out:
#    workclass  maritalStatus  occupation  relationship  race  sex  \
# 0          6              4           0             1     4    1
# 1          5              2           3             0     4    1
# 2          3              0           5             1     4    1
# 3          3              2           5             0     2    1
# 4          3              2          10             5     2    0
#
#    nativeCountry       age  finalweight  educationNumber  capitalGain  \
# 0             39  0.042722    -1.065249         1.120047     0.142487
# 1             39  0.881172    -1.010298         1.120047    -0.147499
# 2             39 -0.033501     0.244576        -0.440830    -0.147499
# 3             39  1.109840     0.425456        -1.221269    -0.147499
# 4              5 -0.795728     1.408683         1.120047    -0.147499
#
#    capitalLoss  hoursperweek
# 0    -0.219153     -0.078956
# 1    -0.219153     -2.331360
# 2    -0.219153     -0.078956
# 3    -0.219153     -0.078956
# 4    -0.219153     -0.078956

# %%
dfScaled.shape
# Out:
# (30725, 13)

# %%
data = dfScaled.drop(['nativeCountry'],axis=1)
target= df['income']

# %% [markdown]
# ## 4. Evaluate Model

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import  XGBClassifier
from imblearn.over_sampling import RandomOverSampler, SMOTE
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score, auc, log_loss, matthews_corrcoef,roc_auc_score, f1_score
from sklearn.model_selection import GridSearchCV, learning_curve,KFold, train_test_split

# %%
def calc_train_error(X_train, y_train, model):
#     '''returns in-sample error for already fit model.'''
    predictions = model.predict(X_train)
    predictProba = model.predict_proba(X_train)
    accuracy = accuracy_score(y_train, predictions)
    f1 = f1_score(y_train, predictions, average='macro')
    roc_auc = roc_auc_score(y_train, predictProba[:,1])
    logloss = log_loss(y_train,predictProba[:,1])
    report = classification_report(y_train, predictions)
    lossBuatan = (abs((y_train-predictProba[:,1]))).mean()
    return { 
        'report': report, 
        'f1' : f1, 
        'roc': roc_auc, 
        'accuracy': accuracy,
        'logloss': logloss,
        'lossBuatan': lossBuatan
    }
    
def calc_validation_error(X_test, y_test, model):
#     '''returns out-of-sample error for already fit model.'''
    predictions = model.predict(X_test)
    predictProba = model.predict_proba(X_test)
    accuracy = accuracy_score(y_test, predictions)
    f1 = f1_score(y_test, predictions, average='macro')
    roc_auc = roc_auc_score(y_test, predictProba[:,1])
    logloss = log_loss(y_test,predictProba[:,1])
    report = classification_report(y_test, predictions)
    lossBuatan = (abs((y_test-predictProba[:,1]))).mean()
    return { 
        'report': report, 
        'f1' : f1, 
        'roc': roc_auc, 
        'accuracy': accuracy,
        'logloss': logloss,
        'lossBuatan':lossBuatan
    }
    
def calc_metrics(X_train, y_train, X_test, y_test, model):
#     '''fits model and returns the in-sample error and out-of-sample error'''
    model.fit(X_train, y_train)
    train_error = calc_train_error(X_train, y_train, model)
    validation_error = calc_validation_error(X_test, y_test, model)
    return train_error, validation_error

# %% [markdown]
# ### Train Test Split

# %%
X_train,X_test,y_train,y_test = train_test_split(data,target,test_size=.3,random_state=101)

# %% [markdown]
# #### 4.1 Logistics Regression

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
train_errors = []
validation_errors = []
for train_index, val_index in kf.split(data, target):
    
    # split data
    X_train, X_val = data.iloc[train_index], data.iloc[val_index]
    y_train, y_val = target.iloc[train_index], target.iloc[val_index]
    
#     # Oversampling data train
#     ros = RandomOverSampler(random_state=101)
#     X_train,y_train = ros.fit_sample(X_train,y_train)
#     smot = SMOTE(random_state=101)
#     X_train,y_train = smot.fit_sample(X_train,y_train)

    # instantiate model
    logreg = LogisticRegression(solver='lbfgs')

    #calculate errors
    train_error, val_error = calc_metrics(X_train, y_train, X_val, y_val, logreg)
    train_errors.append(train_error)
    validation_errors.append(val_error)

# %%
listItem = []

for tr,val in zip(train_errors,validation_errors) :
    listItem.append([tr['accuracy'],val['accuracy'],tr['roc'],val['roc'],tr['f1'],val['f1'],
                     tr['logloss'],val['logloss']])

listItem.append(list(np.mean(listItem,axis=0)))
    
dfEvalLR = pd.DataFrame(listItem, 
                    columns=['Train Accuracy', 'Test Accuracy', 'Train ROC AUC', 'Test ROC AUC', 
                            'Train F1 Score', 'Test F1 Score', 'Train Log Loss', 'Test Log Loss'])
listIndex = list(dfEvalLR.index)
listIndex[-1] = 'Average'
dfEvalLR.index = listIndex
dfEvalLR
# Out:
#          Train Accuracy  Test Accuracy  Train ROC AUC  Test ROC AUC  \
# 0              0.819569       0.824410       0.852123      0.853297
# 1              0.819284       0.824410       0.850605      0.859908
# 2              0.819406       0.825224       0.852234      0.853332
# 3              0.822254       0.814646       0.853528      0.847914
# 4              0.822417       0.811717       0.854035      0.846360
# Average        0.820586       0.820081       0.852505      0.852162
#
#          Train F1 Score  Test F1 Score  Train Log Loss  Test Log Loss
# 0              0.722757       0.735856        0.391606       0.387788
# 1              0.722381       0.727383        0.393052       0.381962
# 2              0.722916       0.733195        0.392107       0.385706
# 3              0.729587       0.709586        0.389263       0.397006
# 4              0.726038       0.714156        0.387534       0.404067
# Average        0.724735       0.724035        0.390712       0.391306

# %%
for item,rep in zip(range(1,6),train_errors) :
    print('Report Train ke ',item,':')
    print(rep['report'])
# Out:
# Report Train ke  1 :
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89     18469
#            1       0.71      0.46      0.56      6111
#
#     accuracy                           0.82     24580
#    macro avg       0.78      0.70      0.72     24580
# weighted avg       0.81      0.82      0.81     24580
#
# Report Train ke  2 :
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89     18450
#            1       0.71      0.46      0.56      6130
#
#     accuracy                           0.82     24580
#    macro avg       0.78      0.70      0.72     24580
# weighted avg       0.81      0.82      0.80     24580
#
# Report Train ke  3 :
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89     18443
#            1       0.72      0.46      0.56      6137
#
#     accuracy                           0.82     24580
#    macro avg       0.78      0.70      0.72     24580
# weighted avg       0.81      0.82      0.80     24580
#
# Report Train ke  4 :
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89     18426
#            1       0.72      0.47      0.57      6154
#
#     accuracy                           0.82     24580
#    macro avg       0.78      0.71      0.73     24580
# weighted avg       0.81      0.82      0.81     24580
#
# Report Train ke  5 :
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89     18512
#            1       0.72      0.46      0.56      6068
#
#     accuracy                           0.82     24580
#    macro avg       0.78      0.70      0.73     24580
# weighted avg       0.81      0.82      0.81     24580

# %%
for item,rep in zip(range(1,6),validation_errors) :
    print('Report Test ke ',item,':')
    print(rep['report'])
# Out:
# Report Test ke  1 :
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89      4606
#            1       0.72      0.49      0.58      1539
#
#     accuracy                           0.82      6145
#    macro avg       0.78      0.71      0.74      6145
# weighted avg       0.81      0.82      0.81      6145
#
# Report Test ke  2 :
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      4625
#            1       0.73      0.46      0.56      1520
#
#     accuracy                           0.82      6145
#    macro avg       0.79      0.70      0.73      6145
# weighted avg       0.81      0.82      0.81      6145
#
# Report Test ke  3 :
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89      4632
#            1       0.71      0.48      0.58      1513
#
#     accuracy                           0.83      6145
#    macro avg       0.78      0.71      0.73      6145
# weighted avg       0.81      0.83      0.81      6145
#
# Report Test ke  4 :
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.88      4649
#            1       0.69      0.44      0.53      1496
#
#     accuracy                           0.81      6145
#    macro avg       0.76      0.69      0.71      6145
# weighted avg       0.80      0.81      0.80      6145
#
# Report Test ke  5 :
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88      4563
#            1       0.72      0.44      0.55      1582
#
#     accuracy                           0.81      6145
#    macro avg       0.77      0.69      0.71      6145
# weighted avg       0.80      0.81      0.80      6145

# %%
np.linspace(0.3, 1.0, 5)
train_sizes, train_scores, test_scores = learning_curve(estimator=logreg,
                                                       X=data,
                                                       y=target,
                                                       train_sizes=np.linspace(0.3, 1.0, 5),
                                                       cv=10,
                                                       scoring='accuracy')

print('\nTrain Scores : ')
print(train_scores)
# Mean value of accuracy against training data
train_mean = np.mean(train_scores, axis=1)
print('\nTrain Mean : ')
print(train_mean)
print('\nTrain Size : ')
print(train_sizes)
# Standard deviation of training accuracy per number of training samples
train_std = np.std(train_scores, axis=1)
print('\nTrain Std : ')
print(train_std)

# Same as above for test data
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

print('\nTest Scores : ')
print(test_scores)
print('\nTest Mean : ')
print(test_mean)
print('\nTest Std : ')
print(test_std)

# Plot training accuracies 
plt.plot(train_sizes, train_mean, color='red', marker='o', label='Training Accuracy')
# Plot the variance of training accuracies
plt.fill_between(train_sizes,
                train_mean + train_std,
                train_mean - train_std,
                alpha=0.15, color='red')

# Plot for test data as training data
plt.plot(train_sizes, test_mean, color='blue', linestyle='--', marker='s', 
        label='Test Accuracy')
plt.fill_between(train_sizes,
                test_mean + test_std,
                test_mean - test_std,
                alpha=0.15, color='blue')

plt.xlabel('Number of training samples')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Train Scores :
# [[0.81808318 0.81711875 0.81603376 0.81555154 0.81555154 0.81555154
#   0.81555154 0.81555154 0.81555154 0.81555154]
#  [0.81955231 0.81863865 0.81818182 0.81886706 0.81818182 0.81955231
#   0.81955231 0.81955231 0.81955231 0.81955231]
#  [0.8214544  0.82034162 0.81956268 0.82067546 0.82000779 0.81922884
#   0.82000779 0.82000779 0.82000779 0.82000779]
#  [0.82171664 0.82031387 0.82027003 0.82140978 0.8202262  0.81956865
#   0.8211906  0.81921796 0.82044538 0.82044538]
#  [0.82120642 0.82070013 0.82023    0.82098944 0.82055548 0.81972371
#   0.82149573 0.81965138 0.82048315 0.82048315]]
#
# Train Mean :
# [0.81600964 0.81911832 0.8201302  0.82048045 0.82055186]
#
# Train Size :
# [ 8295 13134 17973 22812 27652]
#
# Train Std :
# [0.00083662 0.00056368 0.00057489 0.00073896 0.00056058]
#
# Test Scores :
# [[0.81646599 0.82004556 0.81516433 0.81548975 0.82069639 0.82617188
#   0.80957031 0.82877604 0.82259115 0.82291667]
#  [0.81548975 0.82134722 0.81711682 0.81679141 0.82167263 0.82682292
#   0.8125     0.82617188 0.82389323 0.82486979]
#  [0.81581516 0.82264888 0.81744224 0.81646599 0.82004556 0.82714844
#   0.8108724  0.82682292 0.82454427 0.82356771]
#  [0.81548975 0.82232346 0.81809307 0.81581516 0.81939473 0.82747396
#   0.81119792 0.8264974  0.82617188 0.82324219]
#  [0.81581516 0.82134722 0.81776765 0.81516433 0.82069639 0.828125
#   0.8108724  0.82779948 0.82584635 0.8219401 ]]
#
# Test Mean :
# [0.81978881 0.82066756 0.82053736 0.82056995 0.82053741]
#
# Test Std :
# [0.00543476 0.00467838 0.00504995 0.00517846 0.00541661]

# %%
predictProbaTrain=logreg.predict_proba(X_train)

# %%
pred = predictProbaTrain[:,1]
fpr, tpr, threshold = roc_curve(y_train, pred)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characterisitc')
plt.plot(fpr, tpr, 'b', label='AUC = {}'.format(round(roc_auc,2)))
plt.legend(loc = 'lower right')
plt.plot([0,1], [0,1], 'r--')
# plt.xlim([0,1])
# plt.ylim([0,1])
plt.ylabel('True Positive rate')
plt.xlabel('False Positive rate')
plt.show()

# %%
predictProbaTest=logreg.predict_proba(X_test)

# %%
preds = predictProbaTest[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characterisitc')
plt.plot(fpr, tpr, 'b', label='AUC = {}'.format(round(roc_auc,2)))
plt.legend(loc = 'lower right')
plt.plot([0,1], [0,1], 'r--')
# plt.xlim([0,1])
# plt.ylim([0,1])
plt.ylabel('True Positive rate')
plt.xlabel('False Positive rate')
plt.show()

# %% [markdown]
# #### 4.2 Decision Tree

# %%
train_errors = []
validation_errors = []
for train_index, val_index in kf.split(data, target):
    
    # split data
    X_train, X_val = data.iloc[train_index], data.iloc[val_index]
    y_train, y_val = target.iloc[train_index], target.iloc[val_index]
    
#     print(len(X_val), (len(X_train) + len(X_val)))
    # Oversampling data train
#     ros = RandomOverSampler(random_state=101)
#     X_train,y_train = ros.fit_sample(X_train,y_train)
#     smot = SMOTE(random_state=101)
#     X_train,y_train = smot.fit_sample(X_train,y_train)

    # instantiate model
    dtree = DecisionTreeClassifier(max_depth=7,min_samples_leaf=25)

    #calculate errors
    train_error, val_error = calc_metrics(X_train, y_train, X_val, y_val, dtree)

    # append to appropriate list
    train_errors.append(train_error)
    validation_errors.append(val_error)

# %%
listItem = []

for tr,val in zip(train_errors,validation_errors) :
    listItem.append([tr['accuracy'],val['accuracy'],tr['roc'],val['roc'],tr['f1'],val['f1'],
                     tr['logloss'],val['logloss'],tr['lossBuatan'],val['lossBuatan']])

listItem.append(list(np.mean(listItem,axis=0)))
    
dfEvalDTC = pd.DataFrame(listItem, 
                    columns=['Train Accuracy', 'Test Accuracy', 'Train ROC AUC', 'Test ROC AUC', 
                            'Train F1 Score', 'Test F1 Score', 'Train Log Loss', 'Test Log Loss','Train loss Buatan','Test Loss Buatan'])
listIndex = list(dfEvalDTC.index)
listIndex[-1] = 'Average'
dfEvalDTC.index = listIndex
dfEvalDTC
# Out:
#          Train Accuracy  Test Accuracy  Train ROC AUC  Test ROC AUC  \
# 0              0.852807       0.855492       0.903954      0.904781
# 1              0.853417       0.852238       0.901448      0.899928
# 2              0.853784       0.849959       0.903900      0.892529
# 3              0.853417       0.847681       0.905978      0.895996
# 4              0.855574       0.849146       0.905173      0.901990
# Average        0.853800       0.850903       0.904091      0.899045
#
#          Train F1 Score  Test F1 Score  Train Log Loss  Test Log Loss  \
# 0              0.778134       0.783896        0.315910       0.327321
# 1              0.781085       0.778905        0.320099       0.320277
# 2              0.783394       0.777851        0.317220       0.335399
# 3              0.781875       0.768555        0.313733       0.346337
# 4              0.783288       0.776216        0.313240       0.329207
# Average        0.781555       0.777085        0.316040       0.331708
#
#          Train loss Buatan  Test Loss Buatan
# 0                 0.202946          0.202181
# 1                 0.203857          0.203162
# 2                 0.202073          0.208220
# 3                 0.201898          0.206639
# 4                 0.201047          0.203555
# Average           0.202364          0.204751

# %%
for item,rep in zip(range(1,6),train_errors) :
    print('Report Train ke ',item,':')
    print(rep['report'])
# Out:
# Report Train ke  1 :
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.91     18469
#            1       0.80      0.55      0.65      6111
#
#     accuracy                           0.85     24580
#    macro avg       0.83      0.75      0.78     24580
# weighted avg       0.85      0.85      0.84     24580
#
# Report Train ke  2 :
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91     18450
#            1       0.79      0.56      0.66      6130
#
#     accuracy                           0.85     24580
#    macro avg       0.83      0.75      0.78     24580
# weighted avg       0.85      0.85      0.84     24580
#
# Report Train ke  3 :
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91     18443
#            1       0.79      0.57      0.66      6137
#
#     accuracy                           0.85     24580
#    macro avg       0.83      0.76      0.78     24580
# weighted avg       0.85      0.85      0.85     24580
#
# Report Train ke  4 :
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91     18426
#            1       0.79      0.56      0.66      6154
#
#     accuracy                           0.85     24580
#    macro avg       0.83      0.76      0.78     24580
# weighted avg       0.85      0.85      0.84     24580
#
# Report Train ke  5 :
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91     18512
#            1       0.79      0.56      0.66      6068
#
#     accuracy                           0.86     24580
#    macro avg       0.83      0.76      0.78     24580
# weighted avg       0.85      0.86      0.85     24580

# %%
for item,rep in zip(range(1,6),validation_errors) :
    print('Report Test ke ',item,':')
    print(rep['report'])
# Out:
# Report Test ke  1 :
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91      4606
#            1       0.80      0.56      0.66      1539
#
#     accuracy                           0.86      6145
#    macro avg       0.84      0.76      0.78      6145
# weighted avg       0.85      0.86      0.85      6145
#
# Report Test ke  2 :
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91      4625
#            1       0.78      0.56      0.65      1520
#
#     accuracy                           0.85      6145
#    macro avg       0.82      0.75      0.78      6145
# weighted avg       0.85      0.85      0.84      6145
#
# Report Test ke  3 :
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90      4632
#            1       0.76      0.57      0.65      1513
#
#     accuracy                           0.85      6145
#    macro avg       0.82      0.76      0.78      6145
# weighted avg       0.84      0.85      0.84      6145
#
# Report Test ke  4 :
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      4649
#            1       0.77      0.54      0.63      1496
#
#     accuracy                           0.85      6145
#    macro avg       0.81      0.74      0.77      6145
# weighted avg       0.84      0.85      0.84      6145
#
# Report Test ke  5 :
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.90      4563
#            1       0.81      0.54      0.65      1582
#
#     accuracy                           0.85      6145
#    macro avg       0.83      0.75      0.78      6145
# weighted avg       0.85      0.85      0.84      6145

# %%
np.linspace(0.3, 1.0, 5)
train_sizes, train_scores, test_scores = learning_curve(estimator=dtree,
                                                       X=data,
                                                       y=target,
                                                       train_sizes=np.linspace(0.3, 0.9, 5),
                                                       cv=10,
                                                       scoring='accuracy')

print('\nTrain Scores : ')
print(train_scores)
# Mean value of accuracy against training data
train_mean = np.mean(train_scores, axis=1)
print('\nTrain Mean : ')
print(train_mean)
print('\nTrain Size : ')
print(train_sizes)
# Standard deviation of training accuracy per number of training samples
train_std = np.std(train_scores, axis=1)
print('\nTrain Std : ')
print(train_std)

# Same as above for test data
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

print('\nTest Scores : ')
print(test_scores)
print('\nTest Mean : ')
print(test_mean)
print('\nTest Std : ')
print(test_std)

# Plot training accuracies 
plt.plot(train_sizes, train_mean, color='red', marker='o', label='Training Accuracy')
# Plot the variance of training accuracies
plt.fill_between(train_sizes,
                train_mean + train_std,
                train_mean - train_std,
                alpha=0.15, color='red')

# Plot for test data as training data
plt.plot(train_sizes, test_mean, color='blue', linestyle='--', marker='s', 
        label='Test Accuracy')
plt.fill_between(train_sizes,
                test_mean + test_std,
                test_mean - test_std,
                alpha=0.15, color='blue')

plt.xlabel('Number of training samples')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Train Scores :
# [[0.85461121 0.84870404 0.84846293 0.85063291 0.85063291 0.85063291
#   0.85063291 0.85063291 0.85063291 0.85063291]
#  [0.85742988 0.85100056 0.85156313 0.85156313 0.85228643 0.85244716
#   0.85244716 0.85244716 0.85244716 0.85244716]
#  [0.85709119 0.85353505 0.85220903 0.8525104  0.85443915 0.85419806
#   0.85516244 0.85516244 0.85516244 0.85516244]
#  [0.85597184 0.85471816 0.8542842  0.85423598 0.85520035 0.85438064
#   0.85486282 0.85399489 0.85399489 0.85399489]
#  [0.85755043 0.8561842  0.85658603 0.85614402 0.85706823 0.85481797
#   0.85614402 0.85493852 0.85562163 0.85437595]]
#
# Train Mean :
# [0.85062086 0.85260789 0.85446326 0.85456387 0.8559431 ]
#
# Train Size :
# [ 8295 12443 16591 20739 24886]
#
# Train Std :
# [0.00155739 0.00168079 0.00136708 0.00060755 0.00096104]
#
# Test Scores :
# [[0.83664172 0.84640417 0.84542792 0.83468923 0.84770582 0.8421224
#   0.8515625  0.8531901  0.85481771 0.84602865]
#  [0.83664172 0.84835665 0.84640417 0.83891962 0.84965831 0.84895833
#   0.8531901  0.85677083 0.85677083 0.84602865]
#  [0.83761796 0.85063456 0.84803124 0.84119753 0.85193622 0.85091146
#   0.84765625 0.85904948 0.85872396 0.84505208]
#  [0.84152294 0.85063456 0.85193622 0.84380085 0.85030914 0.85351562
#   0.8515625  0.86002604 0.859375   0.84309896]
#  [0.84249919 0.85388871 0.85030914 0.84672958 0.85193622 0.85058594
#   0.85351562 0.85807292 0.85807292 0.84309896]]
#
# Test Mean :
# [0.84585902 0.84816992 0.84908107 0.85057818 0.85087092]
#
# Test Std :
# [0.00627806 0.00634189 0.00647447 0.00601691 0.00518662]

# %%
predictProbaTrain=dtree.predict_proba(X_train)

# %%
pred = predictProbaTrain[:,1]
fpr, tpr, threshold = roc_curve(y_train, pred)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characterisitc')
plt.plot(fpr, tpr, 'b', label='AUC = {}'.format(round(roc_auc,2)))
plt.legend(loc = 'lower right')
plt.plot([0,1], [0,1], 'r--')
# plt.xlim([0,1])
# plt.ylim([0,1])
plt.ylabel('True Positive rate')
plt.xlabel('False Positive rate')
plt.show()

# %%
predictProbaTest=dtree.predict_proba(X_test)

# %%
preds = predictProbaTest[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characterisitc')
plt.plot(fpr, tpr, 'b', label='AUC = {}'.format(round(roc_auc,2)))
plt.legend(loc = 'lower right')
plt.plot([0,1], [0,1], 'r--')
# plt.xlim([0,1])
# plt.ylim([0,1])
plt.ylabel('True Positive rate')
plt.xlabel('False Positive rate')
plt.show()

# %%
coef1 = pd.Series(dtree.feature_importances_,data.columns).sort_values(ascending=False)
coef1.plot(kind='bar', title='Feature Importances')

# %% [markdown]
# #### 4.3 Random Forest

# %%
train_errors = []
validation_errors = []
for train_index, val_index in kf.split(data, target):
    
    # split data
    X_train, X_val = data.iloc[train_index], data.iloc[val_index]
    y_train, y_val = target.iloc[train_index], target.iloc[val_index]
    
#     print(len(X_val), (len(X_train) + len(X_val)))
    # Oversampling data train
#     ros = RandomOverSampler(random_state=101)
#     X_train,y_train = ros.fit_sample(X_train,y_train)
#     smot = SMOTE(random_state=101)
#     X_train,y_train = smot.fit_sample(X_train,y_train)
    
    # instantiate model
    rfc = RandomForestClassifier(n_estimators=300,max_depth=3,min_samples_leaf=10,random_state=101)

    #calculate errors
    train_error, val_error = calc_metrics(X_train, y_train, X_val, y_val, rfc)

    # append to appropriate list
    train_errors.append(train_error)
    validation_errors.append(val_error)

# %%
listItem = []

for tr,val in zip(train_errors,validation_errors) :
    listItem.append([tr['accuracy'],val['accuracy'],tr['roc'],val['roc'],tr['f1'],val['f1'],
                     tr['logloss'],val['logloss']])

listItem.append(list(np.mean(listItem,axis=0)))
    
dfEvalRFC = pd.DataFrame(listItem, 
                    columns=['Train Accuracy', 'Test Accuracy', 'Train ROC AUC', 'Test ROC AUC', 
                            'Train F1 Score', 'Test F1 Score', 'Train Log Loss', 'Test Log Loss'])
listIndex = list(dfEvalRFC.index)
listIndex[-1] = 'Average'
dfEvalRFC.index = listIndex
dfEvalRFC
# Out:
#          Train Accuracy  Test Accuracy  Train ROC AUC  Test ROC AUC  \
# 0              0.835761       0.842474       0.890173      0.890891
# 1              0.835069       0.838080       0.888032      0.896021
# 2              0.838365       0.838080       0.891045      0.879640
# 3              0.835842       0.832872       0.890010      0.889495
# 4              0.836046       0.828316       0.890126      0.888864
# Average        0.836216       0.835964       0.889877      0.888982
#
#          Train F1 Score  Test F1 Score  Train Log Loss  Test Log Loss
# 0              0.726987       0.742322        0.384047       0.383972
# 1              0.726514       0.730727        0.386121       0.378588
# 2              0.737404       0.734871        0.382884       0.387843
# 3              0.727865       0.715598        0.384241       0.382557
# 4              0.726031       0.717944        0.382228       0.390133
# Average        0.728961       0.728292        0.383904       0.384618

# %%
for item,rep in zip(range(1,6),train_errors) :
    print('Report Train ke ',item,':')
    print(rep['report'])
# Out:
# Report Train ke  1 :
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90     18469
#            1       0.85      0.41      0.55      6111
#
#     accuracy                           0.84     24580
#    macro avg       0.84      0.69      0.73     24580
# weighted avg       0.84      0.84      0.81     24580
#
# Report Train ke  2 :
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90     18450
#            1       0.85      0.41      0.55      6130
#
#     accuracy                           0.84     24580
#    macro avg       0.84      0.69      0.73     24580
# weighted avg       0.84      0.84      0.81     24580
#
# Report Train ke  3 :
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90     18443
#            1       0.84      0.44      0.57      6137
#
#     accuracy                           0.84     24580
#    macro avg       0.84      0.70      0.74     24580
# weighted avg       0.84      0.84      0.82     24580
#
# Report Train ke  4 :
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90     18426
#            1       0.86      0.41      0.56      6154
#
#     accuracy                           0.84     24580
#    macro avg       0.85      0.69      0.73     24580
# weighted avg       0.84      0.84      0.81     24580
#
# Report Train ke  5 :
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90     18512
#            1       0.85      0.41      0.55      6068
#
#     accuracy                           0.84     24580
#    macro avg       0.84      0.69      0.73     24580
# weighted avg       0.84      0.84      0.81     24580

# %%
for item,rep in zip(range(1,6),validation_errors) :
    print('Report Test ke ',item,':')
    print(rep['report'])
# Out:
# Report Test ke  1 :
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.90      4606
#            1       0.87      0.44      0.58      1539
#
#     accuracy                           0.84      6145
#    macro avg       0.85      0.71      0.74      6145
# weighted avg       0.85      0.84      0.82      6145
#
# Report Test ke  2 :
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.90      4625
#            1       0.85      0.42      0.56      1520
#
#     accuracy                           0.84      6145
#    macro avg       0.84      0.70      0.73      6145
# weighted avg       0.84      0.84      0.82      6145
#
# Report Test ke  3 :
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90      4632
#            1       0.82      0.43      0.57      1513
#
#     accuracy                           0.84      6145
#    macro avg       0.83      0.70      0.73      6145
# weighted avg       0.84      0.84      0.82      6145
#
# Report Test ke  4 :
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.90      4649
#            1       0.83      0.39      0.53      1496
#
#     accuracy                           0.83      6145
#    macro avg       0.83      0.68      0.72      6145
# weighted avg       0.83      0.83      0.81      6145
#
# Report Test ke  5 :
#               precision    recall  f1-score   support
#
#            0       0.82      0.98      0.89      4563
#            1       0.87      0.39      0.54      1582
#
#     accuracy                           0.83      6145
#    macro avg       0.84      0.69      0.72      6145
# weighted avg       0.83      0.83      0.80      6145

# %%
np.linspace(0.3, 1.0, 5)
train_sizes, train_scores, test_scores = learning_curve(estimator=rfc,
                                                       X=data,
                                                       y=target,
                                                       train_sizes=np.linspace(0.3, 0.9, 5),
                                                       cv=10,
                                                       scoring='accuracy')

print('\nTrain Scores : ')
print(train_scores)
# Mean value of accuracy against training data
train_mean = np.mean(train_scores, axis=1)
print('\nTrain Mean : ')
print(train_mean)
print('\nTrain Size : ')
print(train_sizes)
# Standard deviation of training accuracy per number of training samples
train_std = np.std(train_scores, axis=1)
print('\nTrain Std : ')
print(train_std)

# Same as above for test data
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

print('\nTest Scores : ')
print(test_scores)
print('\nTest Mean : ')
print(test_mean)
print('\nTest Std : ')
print(test_std)

# Plot training accuracies 
plt.plot(train_sizes, train_mean, color='red', marker='o', label='Training Accuracy')
# Plot the variance of training accuracies
plt.fill_between(train_sizes,
                train_mean + train_std,
                train_mean - train_std,
                alpha=0.15, color='red')

# Plot for test data as training data
plt.plot(train_sizes, test_mean, color='blue', linestyle='--', marker='s', 
        label='Test Accuracy')
plt.fill_between(train_sizes,
                test_mean + test_std,
                test_mean - test_std,
                alpha=0.15, color='blue')

plt.xlabel('Number of training samples')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Train Scores :
# [[0.83568415 0.83001808 0.826522   0.82869198 0.82869198 0.82869198
#   0.82869198 0.82869198 0.82869198 0.82869198]
#  [0.83733826 0.83492727 0.82793539 0.83637386 0.82769429 0.83058748
#   0.83058748 0.83058748 0.83058748 0.83058748]
#  [0.83792418 0.83647761 0.82954614 0.83026942 0.83219818 0.83382557
#   0.83611597 0.83611597 0.83611597 0.83611597]
#  [0.83943295 0.8385168  0.83581658 0.83740778 0.83538261 0.83649163
#   0.83697382 0.83504508 0.83504508 0.83504508]
#  [0.8413164  0.83999036 0.83440489 0.83774009 0.83673551 0.83814193
#   0.83757936 0.83565057 0.83717753 0.83649441]]
#
# Train Mean :
# [0.82930681 0.83172065 0.8344705  0.83651574 0.83752311]
#
# Train Size :
# [ 8295 12443 16591 20739 24886]
#
# Train Std :
# [0.00227107 0.00316943 0.00272515 0.00147587 0.00189571]
#
# Test Scores :
# [[0.82655386 0.83208591 0.82492678 0.82687927 0.82850635 0.83007812
#   0.8219401  0.83821615 0.83854167 0.82324219]
#  [0.82948259 0.83436381 0.82590303 0.83241132 0.82622844 0.83105469
#   0.82389323 0.83984375 0.83919271 0.82486979]
#  [0.83013342 0.83468923 0.82655386 0.82590303 0.82980801 0.83268229
#   0.828125   0.84667969 0.83821615 0.8297526 ]
#  [0.83176049 0.83729255 0.83826879 0.83013342 0.83826879 0.8375651
#   0.82682292 0.8453776  0.83886719 0.82877604]
#  [0.83338757 0.83989587 0.83273674 0.82915718 0.83729255 0.83854167
#   0.82779948 0.84700521 0.83984375 0.83072917]]
#
# Test Mean :
# [0.82909704 0.83072434 0.83225433 0.83531329 0.83563892]
#
# Test Std :
# [0.00544869 0.00544993 0.0059697  0.00542821 0.00563225]

# %%
predictProbaTrain=rfc.predict_proba(X_train)

# %%
pred = predictProbaTrain[:,1]
fpr, tpr, threshold = roc_curve(y_train, pred)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characterisitc')
plt.plot(fpr, tpr, 'b', label='AUC = {}'.format(round(roc_auc,2)))
plt.legend(loc = 'lower right')
plt.plot([0,1], [0,1], 'r--')
# plt.xlim([0,1])
# plt.ylim([0,1])
plt.ylabel('True Positive rate')
plt.xlabel('False Positive rate')
plt.show()

# %%
predictProbaTest=rfc.predict_proba(X_test)

# %%
preds = predictProbaTest[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characterisitc')
plt.plot(fpr, tpr, 'b', label='AUC = {}'.format(round(roc_auc,2)))
plt.legend(loc = 'lower right')
plt.plot([0,1], [0,1], 'r--')
# plt.xlim([0,1])
# plt.ylim([0,1])
plt.ylabel('True Positive rate')
plt.xlabel('False Positive rate')
plt.show()

# %%
coef1 = pd.Series(rfc.feature_importances_,data.columns).sort_values(ascending=False)
coef1.plot(kind='bar', title='Feature Importances')

# %% [markdown]
# #### 4.4 XGBoost

# %%
train_errors = []
validation_errors = []
for train_index, val_index in kf.split(data, target):
    
    # split data
    X_train, X_val = data.iloc[train_index], data.iloc[val_index]
    y_train, y_val = target.iloc[train_index], target.iloc[val_index]
    
#     print(len(X_val), (len(X_train) + len(X_val)))
    # Oversampling data train
#     ros = RandomOverSampler(random_state=101)
#     X_ros,y_train = ros.fit_sample(X_train,y_train)
#     smot = SMOTE(random_state=101)
#     X_smot,y_train = smot.fit_sample(X_train,y_train)
#     X_train = pd.DataFrame(X_smot, columns=X_train.columns)

    # instantiate model
    xgb = XGBClassifier(max_depth=10,min_child_weight=10, n_estimators=250, learning_rate=0.1)

    #calculate errors
    train_error, val_error = calc_metrics(X_train, y_train, X_val, y_val, xgb)

    # append to appropriate list
    train_errors.append(train_error)
    validation_errors.append(val_error)

# %%
listItem = []

for tr,val in zip(train_errors,validation_errors) :
    listItem.append([tr['accuracy'],val['accuracy'],tr['roc'],val['roc'],tr['f1'],val['f1'],
                     tr['logloss'],val['logloss']])

listItem.append(list(np.mean(listItem,axis=0)))
    
dfEvalXGB = pd.DataFrame(listItem, 
                    columns=['Train Accuracy', 'Test Accuracy', 'Train ROC AUC', 'Test ROC AUC', 
                            'Train F1 Score', 'Test F1 Score', 'Train Log Loss', 'Test Log Loss'])
listIndex = list(dfEvalXGB.index)
listIndex[-1] = 'Average'
dfEvalXGB.index = listIndex
dfEvalXGB
# Out:
#          Train Accuracy  Test Accuracy  Train ROC AUC  Test ROC AUC  \
# 0              0.900732       0.869650       0.958033      0.925431
# 1              0.898779       0.871115       0.956759      0.927934
# 2              0.902889       0.864443       0.960502      0.920524
# 3              0.899390       0.870464       0.958479      0.922584
# 4              0.903295       0.860212       0.959847      0.920581
# Average        0.901017       0.867177       0.958724      0.923411
#
#          Train F1 Score  Test F1 Score  Train Log Loss  Test Log Loss
# 0              0.861317       0.818069        0.227307       0.287521
# 1              0.858691       0.819192        0.230012       0.282428
# 2              0.864730       0.809130        0.222369       0.294331
# 3              0.859108       0.816929        0.227001       0.291331
# 4              0.863962       0.803172        0.222649       0.302509
# Average        0.861561       0.813298        0.225868       0.291624

# %%
for item,rep in zip(range(1,6),train_errors) :
    print('Report Train ke ',item,':')
    print(rep['report'])
# Out:
# Report Train ke  1 :
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.94     18469
#            1       0.84      0.74      0.79      6111
#
#     accuracy                           0.90     24580
#    macro avg       0.88      0.85      0.86     24580
# weighted avg       0.90      0.90      0.90     24580
#
# Report Train ke  2 :
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93     18450
#            1       0.84      0.73      0.78      6130
#
#     accuracy                           0.90     24580
#    macro avg       0.88      0.84      0.86     24580
# weighted avg       0.90      0.90      0.90     24580
#
# Report Train ke  3 :
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     18443
#            1       0.85      0.74      0.79      6137
#
#     accuracy                           0.90     24580
#    macro avg       0.88      0.85      0.86     24580
# weighted avg       0.90      0.90      0.90     24580
#
# Report Train ke  4 :
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93     18426
#            1       0.85      0.73      0.78      6154
#
#     accuracy                           0.90     24580
#    macro avg       0.88      0.84      0.86     24580
# weighted avg       0.90      0.90      0.90     24580
#
# Report Train ke  5 :
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     18512
#            1       0.85      0.74      0.79      6068
#
#     accuracy                           0.90     24580
#    macro avg       0.88      0.85      0.86     24580
# weighted avg       0.90      0.90      0.90     24580

# %%
for item,rep in zip(range(1,6),validation_errors) :
    print('Report Test ke ',item,':')
    print(rep['report'])
# Out:
# Report Test ke  1 :
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.91      4606
#            1       0.78      0.67      0.72      1539
#
#     accuracy                           0.87      6145
#    macro avg       0.84      0.80      0.82      6145
# weighted avg       0.87      0.87      0.87      6145
#
# Report Test ke  2 :
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.92      4625
#            1       0.77      0.68      0.72      1520
#
#     accuracy                           0.87      6145
#    macro avg       0.84      0.81      0.82      6145
# weighted avg       0.87      0.87      0.87      6145
#
# Report Test ke  3 :
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      4632
#            1       0.76      0.66      0.71      1513
#
#     accuracy                           0.86      6145
#    macro avg       0.83      0.80      0.81      6145
# weighted avg       0.86      0.86      0.86      6145
#
# Report Test ke  4 :
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.92      4649
#            1       0.76      0.68      0.72      1496
#
#     accuracy                           0.87      6145
#    macro avg       0.83      0.80      0.82      6145
# weighted avg       0.87      0.87      0.87      6145
#
# Report Test ke  5 :
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      4563
#            1       0.79      0.63      0.70      1582
#
#     accuracy                           0.86      6145
#    macro avg       0.83      0.78      0.80      6145
# weighted avg       0.86      0.86      0.85      6145

# %%
np.linspace(0.3, 1.0, 5)
train_sizes, train_scores, test_scores = learning_curve(estimator=xgb,
                                                       X=data,
                                                       y=target,
                                                       train_sizes=np.linspace(0.3, 1.0, 5),
                                                       cv=10,
                                                       scoring='accuracy')

print('\nTrain Scores : ')
print(train_scores)
# Mean value of accuracy against training data
train_mean = np.mean(train_scores, axis=1)
print('\nTrain Mean : ')
print(train_mean)
print('\nTrain Size : ')
print(train_sizes)
# Standard deviation of training accuracy per number of training samples
train_std = np.std(train_scores, axis=1)
print('\nTrain Std : ')
print(train_std)

# Same as above for test data
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

print('\nTest Scores : ')
print(test_scores)
print('\nTest Mean : ')
print(test_mean)
print('\nTest Std : ')
print(test_std)

# Plot training accuracies 
plt.plot(train_sizes, train_mean, color='red', marker='o', label='Training Accuracy')
# Plot the variance of training accuracies
plt.fill_between(train_sizes,
                train_mean + train_std,
                train_mean - train_std,
                alpha=0.15, color='red')

# Plot for test data as training data
plt.plot(train_sizes, test_mean, color='blue', linestyle='--', marker='s', 
        label='Test Accuracy')
plt.fill_between(train_sizes,
                test_mean + test_std,
                test_mean - test_std,
                alpha=0.15, color='blue')

plt.xlabel('Number of training samples')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Train Scores :
# [[0.91754069 0.92091621 0.92393008 0.92356841 0.92356841 0.92356841
#   0.92356841 0.92356841 0.92356841 0.92356841]
#  [0.90916705 0.91015684 0.91411603 0.91472514 0.91167961 0.91137506
#   0.91137506 0.91137506 0.91137506 0.91137506]
#  [0.90802871 0.90480165 0.9073054  0.9083069  0.90569187 0.90813999
#   0.90491292 0.90491292 0.90491292 0.90491292]
#  [0.90084166 0.89834298 0.9018499  0.90128003 0.90246362 0.90272664
#   0.90206909 0.90145537 0.90132386 0.90132386]
#  [0.89942861 0.89657168 0.89895848 0.90011572 0.89899465 0.89856068
#   0.9000434  0.90196008 0.89798206 0.89946478]]
#
# Train Mean :
# [0.92273659 0.911672   0.90619262 0.9013677  0.89920801]
#
# Train Size :
# [ 8295 13134 17973 22812 27652]
#
# Train Std :
# [0.00191257 0.00155905 0.00146997 0.00114966 0.00134871]
#
# Test Scores :
# [[0.85258705 0.86039701 0.8493329  0.84803124 0.86202408 0.85579427
#   0.85807292 0.86653646 0.86165365 0.85351562]
#  [0.85095997 0.86853238 0.86592906 0.85226163 0.86267491 0.85384115
#   0.86165365 0.87239583 0.86263021 0.86067708]
#  [0.85746827 0.86983404 0.86625447 0.85649203 0.86657989 0.85904948
#   0.85904948 0.87304688 0.86523438 0.86458333]
#  [0.86300033 0.86625447 0.86950862 0.8516108  0.8646274  0.86295573
#   0.86393229 0.87239583 0.86979167 0.86132812]
#  [0.86983404 0.87015945 0.86950862 0.86039701 0.86983404 0.86686198
#   0.86230469 0.8733724  0.87044271 0.86458333]]
#
# Test Mean :
# [0.85679452 0.86115559 0.86375922 0.86454053 0.86772983]
#
# Test Std :
# [0.00567805 0.00667128 0.00526263 0.00547411 0.00388557]

# %%
predictProbaTrain=xgb.predict_proba(X_train)

# %%
pred = predictProbaTrain[:,1]
fpr, tpr, threshold = roc_curve(y_train, pred)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characterisitc')
plt.plot(fpr, tpr, 'b', label='AUC = {}'.format(round(roc_auc,2)))
plt.legend(loc = 'lower right')
plt.plot([0,1], [0,1], 'r--')
# plt.xlim([0,1])
# plt.ylim([0,1])
plt.ylabel('True Positive rate')
plt.xlabel('False Positive rate')
plt.show()

# %%
predictProbaTest=xgb.predict_proba(X_test)

# %%
preds = predictProbaTest[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characterisitc')
plt.plot(fpr, tpr, 'b', label='AUC = {}'.format(round(roc_auc,2)))
plt.legend(loc = 'lower right')
plt.plot([0,1], [0,1], 'r--')
# plt.xlim([0,1])
# plt.ylim([0,1])
plt.ylabel('True Positive rate')
plt.xlabel('False Positive rate')
plt.show()

# %%
coef1 = pd.Series(xgb.feature_importances_,data.columns).sort_values(ascending=False)
coef1.plot(kind='bar', title='Feature Importances')

# %% [markdown]
# #### 4.5 Gradien Boosting

# %%
train_errors = []
validation_errors = []
for train_index, val_index in kf.split(data, target):
    
    # split data
    X_train, X_val = data.iloc[train_index], data.iloc[val_index]
    y_train, y_val = target.iloc[train_index], target.iloc[val_index]
    
#     print(len(X_val), (len(X_train) + len(X_val)))
    # Oversampling data train
#     ros = RandomOverSampler(random_state=101)
#     X_ros,y_train = ros.fit_sample(X_train,y_train)
#     smot = SMOTE(random_state=101)
#     X_smot,y_train = smot.fit_sample(X_train,y_train)
#     X_train = pd.DataFrame(X_smot, columns=X_train.columns)

    # instantiate model
    gbc = GradientBoostingClassifier(max_depth=10, n_estimators=150, learning_rate=0.1)

    #calculate errors
    train_error, val_error = calc_metrics(X_train, y_train, X_val, y_val, gbc)

    # append to appropriate list
    train_errors.append(train_error)
    validation_errors.append(val_error)

# %%
listItem = []

for tr,val in zip(train_errors,validation_errors) :
    listItem.append([tr['accuracy'],val['accuracy'],tr['roc'],val['roc'],tr['f1'],val['f1'],
                     tr['logloss'],val['logloss']])

listItem.append(list(np.mean(listItem,axis=0)))
    
dfEvalGBC = pd.DataFrame(listItem, 
                    columns=['Train Accuracy', 'Test Accuracy', 'Train ROC AUC', 'Test ROC AUC', 
                            'Train F1 Score', 'Test F1 Score', 'Train Log Loss', 'Test Log Loss'])
listIndex = list(dfEvalGBC.index)
listIndex[-1] = 'Average'
dfEvalGBC.index = listIndex
dfEvalGBC
# Out:
#          Train Accuracy  Test Accuracy  Train ROC AUC  Test ROC AUC  \
# 0              0.972335       0.866558       0.996746      0.920480
# 1              0.977828       0.863792       0.997728      0.922998
# 2              0.978519       0.855655       0.997761      0.914372
# 3              0.973718       0.863792       0.996951      0.915527
# 4              0.971562       0.854190       0.996630      0.917421
# Average        0.974793       0.860797       0.997163      0.918160
#
#          Train F1 Score  Test F1 Score  Train Log Loss  Test Log Loss
# 0              0.962500       0.813256        0.109513       0.309189
# 1              0.970065       0.808213        0.101298       0.304702
# 2              0.971026       0.797455        0.100085       0.321874
# 3              0.964443       0.806095        0.107300       0.317199
# 4              0.961186       0.794745        0.108342       0.326807
# Average        0.965844       0.803953        0.105308       0.315954

# %%
for item,rep in zip(range(1,6),train_errors) :
    print('Report Train ke ',item,':')
    print(rep['report'])
# Out:
# Report Train ke  1 :
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     18469
#            1       0.96      0.93      0.94      6111
#
#     accuracy                           0.97     24580
#    macro avg       0.97      0.96      0.96     24580
# weighted avg       0.97      0.97      0.97     24580
#
# Report Train ke  2 :
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     18450
#            1       0.97      0.94      0.95      6130
#
#     accuracy                           0.98     24580
#    macro avg       0.98      0.97      0.97     24580
# weighted avg       0.98      0.98      0.98     24580
#
# Report Train ke  3 :
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     18443
#            1       0.97      0.94      0.96      6137
#
#     accuracy                           0.98     24580
#    macro avg       0.98      0.97      0.97     24580
# weighted avg       0.98      0.98      0.98     24580
#
# Report Train ke  4 :
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     18426
#            1       0.97      0.92      0.95      6154
#
#     accuracy                           0.97     24580
#    macro avg       0.97      0.96      0.96     24580
# weighted avg       0.97      0.97      0.97     24580
#
# Report Train ke  5 :
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     18512
#            1       0.96      0.92      0.94      6068
#
#     accuracy                           0.97     24580
#    macro avg       0.97      0.95      0.96     24580
# weighted avg       0.97      0.97      0.97     24580

# %%
for item,rep in zip(range(1,6),validation_errors) :
    print('Report Test ke ',item,':')
    print(rep['report'])
# Out:
# Report Test ke  1 :
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      4606
#            1       0.77      0.66      0.71      1539
#
#     accuracy                           0.87      6145
#    macro avg       0.83      0.80      0.81      6145
# weighted avg       0.86      0.87      0.86      6145
#
# Report Test ke  2 :
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      4625
#            1       0.76      0.66      0.70      1520
#
#     accuracy                           0.86      6145
#    macro avg       0.83      0.79      0.81      6145
# weighted avg       0.86      0.86      0.86      6145
#
# Report Test ke  3 :
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91      4632
#            1       0.73      0.65      0.69      1513
#
#     accuracy                           0.86      6145
#    macro avg       0.81      0.79      0.80      6145
# weighted avg       0.85      0.86      0.85      6145
#
# Report Test ke  4 :
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      4649
#            1       0.75      0.65      0.70      1496
#
#     accuracy                           0.86      6145
#    macro avg       0.82      0.79      0.81      6145
# weighted avg       0.86      0.86      0.86      6145
#
# Report Test ke  5 :
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      4563
#            1       0.77      0.61      0.68      1582
#
#     accuracy                           0.85      6145
#    macro avg       0.82      0.78      0.79      6145
# weighted avg       0.85      0.85      0.85      6145

# %%
np.linspace(0.3, 1.0, 5)
train_sizes, train_scores, test_scores = learning_curve(estimator=xgb,
                                                       X=data,
                                                       y=target,
                                                       train_sizes=np.linspace(0.3, 1.0, 5),
                                                       cv=10,
                                                       scoring='accuracy')

print('\nTrain Scores : ')
print(train_scores)
# Mean value of accuracy against training data
train_mean = np.mean(train_scores, axis=1)
print('\nTrain Mean : ')
print(train_mean)
print('\nTrain Size : ')
print(train_sizes)
# Standard deviation of training accuracy per number of training samples
train_std = np.std(train_scores, axis=1)
print('\nTrain Std : ')
print(train_std)

# Same as above for test data
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

print('\nTest Scores : ')
print(test_scores)
print('\nTest Mean : ')
print(test_mean)
print('\nTest Std : ')
print(test_std)

# Plot training accuracies 
plt.plot(train_sizes, train_mean, color='red', marker='o', label='Training Accuracy')
# Plot the variance of training accuracies
plt.fill_between(train_sizes,
                train_mean + train_std,
                train_mean - train_std,
                alpha=0.15, color='red')

# Plot for test data as training data
plt.plot(train_sizes, test_mean, color='blue', linestyle='--', marker='s', 
        label='Test Accuracy')
plt.fill_between(train_sizes,
                test_mean + test_std,
                test_mean - test_std,
                alpha=0.15, color='blue')

plt.xlabel('Number of training samples')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Train Scores :
# [[0.91754069 0.92091621 0.92393008 0.92356841 0.92356841 0.92356841
#   0.92356841 0.92356841 0.92356841 0.92356841]
#  [0.90916705 0.91015684 0.91411603 0.91472514 0.91167961 0.91137506
#   0.91137506 0.91137506 0.91137506 0.91137506]
#  [0.90802871 0.90480165 0.9073054  0.9083069  0.90569187 0.90813999
#   0.90491292 0.90491292 0.90491292 0.90491292]
#  [0.90084166 0.89834298 0.9018499  0.90128003 0.90246362 0.90272664
#   0.90206909 0.90145537 0.90132386 0.90132386]
#  [0.89942861 0.89657168 0.89895848 0.90011572 0.89899465 0.89856068
#   0.9000434  0.90196008 0.89798206 0.89946478]]
#
# Train Mean :
# [0.92273659 0.911672   0.90619262 0.9013677  0.89920801]
#
# Train Size :
# [ 8295 13134 17973 22812 27652]
#
# Train Std :
# [0.00191257 0.00155905 0.00146997 0.00114966 0.00134871]
#
# Test Scores :
# [[0.85258705 0.86039701 0.8493329  0.84803124 0.86202408 0.85579427
#   0.85807292 0.86653646 0.86165365 0.85351562]
#  [0.85095997 0.86853238 0.86592906 0.85226163 0.86267491 0.85384115
#   0.86165365 0.87239583 0.86263021 0.86067708]
#  [0.85746827 0.86983404 0.86625447 0.85649203 0.86657989 0.85904948
#   0.85904948 0.87304688 0.86523438 0.86458333]
#  [0.86300033 0.86625447 0.86950862 0.8516108  0.8646274  0.86295573
#   0.86393229 0.87239583 0.86979167 0.86132812]
#  [0.86983404 0.87015945 0.86950862 0.86039701 0.86983404 0.86686198
#   0.86230469 0.8733724  0.87044271 0.86458333]]
#
# Test Mean :
# [0.85679452 0.86115559 0.86375922 0.86454053 0.86772983]
#
# Test Std :
# [0.00567805 0.00667128 0.00526263 0.00547411 0.00388557]

# %%
predictProbaTrain=xgb.predict_proba(X_train)

# %%
pred = predictProbaTrain[:,1]
fpr, tpr, threshold = roc_curve(y_train, pred)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characterisitc')
plt.plot(fpr, tpr, 'b', label='AUC = {}'.format(round(roc_auc,2)))
plt.legend(loc = 'lower right')
plt.plot([0,1], [0,1], 'r--')
# plt.xlim([0,1])
# plt.ylim([0,1])
plt.ylabel('True Positive rate')
plt.xlabel('False Positive rate')
plt.show()

# %%
predictProbaTest=xgb.predict_proba(X_test)

# %%
preds = predictProbaTest[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characterisitc')
plt.plot(fpr, tpr, 'b', label='AUC = {}'.format(round(roc_auc,2)))
plt.legend(loc = 'lower right')
plt.plot([0,1], [0,1], 'r--')
# plt.xlim([0,1])
# plt.ylim([0,1])
plt.ylabel('True Positive rate')
plt.xlabel('False Positive rate')
plt.show()

# %%
coef1 = pd.Series(xgb.feature_importances_,data.columns).sort_values(ascending=False)
coef1.plot(kind='bar', title='Feature Importances')

# %%
outside = ['Accuracy', 'Accuracy', 'Accuracy', 'Accuracy', 'Accuracy','Accuracy', 'Accuracy',
          'ROC_AUC', 'ROC_AUC', 'ROC_AUC', 'ROC_AUC', 'ROC_AUC','ROC_AUC', 'ROC_AUC',
          'F1','F1','F1','F1','F1', 'F1','F1',
          'LogLoss','LogLoss','LogLoss','LogLoss','LogLoss','LogLoss','LogLoss']
inside = [1,2,3,4,5,'Avg','Std', 1,2,3,4,5,'Avg','Std', 1,2,3,4,5,'Avg','Std', 1,2,3,4,5,'Avg','Std']
hier_index = list(zip(outside, inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
acc = []
roc = []
F1 = []
logloss = []

kol = {
    'acc' : 'Test Accuracy',
    'roc' : 'Test ROC AUC',
    'F1' : 'Test F1 Score',
    'logloss' : 'Test Log Loss'
}

for Elr,Edtc, Erfc, Exgb, Egbc in zip(dfEvalLR.iloc[:5].values,dfEvalDTC.iloc[:5].values,dfEvalRFC.iloc[:5].values, dfEvalXGB.iloc[:5].values, dfEvalGBC.iloc[:5].values):
    acc.append([Elr[1],Edtc[1],Erfc[1], Exgb[1], Egbc[1]])
    roc.append([Elr[3],Edtc[3],Erfc[3], Exgb[3], Egbc[3]])
    F1.append([Elr[5],Edtc[5],Erfc[5], Exgb[5], Egbc[5]])
    logloss.append([Elr[7],Edtc[7],Erfc[7], Exgb[7], Egbc[7]])

for i,j in zip([acc,roc,F1,logloss], ['acc','roc','F1','logloss']):
    i.append([dfEvalLR.iloc[:5][kol[j]].mean(),dfEvalDTC.iloc[:5][kol[j]].mean(),dfEvalRFC.iloc[:5][kol[j]].mean(), dfEvalXGB.iloc[:5][kol[j]].mean(), dfEvalGBC.iloc[:5][kol[j]].mean()])
    i.append([dfEvalLR.iloc[:5][kol[j]].std(),dfEvalDTC.iloc[:5][kol[j]].std(),dfEvalRFC.iloc[:5][kol[j]].std(), dfEvalXGB.iloc[:5][kol[j]].std(), dfEvalGBC.iloc[:5][kol[j]].std()])

dfEval = pd.concat([pd.DataFrame(acc),pd.DataFrame(roc),pd.DataFrame(F1),pd.DataFrame(logloss)], axis=0)
dfEval.columns = ['LR','DTC','RFC', 'XGB', 'GBC']
dfEval.index = hier_index
dfEval
# Out:
#                     LR       DTC       RFC       XGB       GBC
# Accuracy 1    0.824410  0.855492  0.842474  0.869650  0.866558
#          2    0.824410  0.852238  0.838080  0.871115  0.863792
#          3    0.825224  0.849959  0.838080  0.864443  0.855655
#          4    0.814646  0.847681  0.832872  0.870464  0.863792
#          5    0.811717  0.849146  0.828316  0.860212  0.854190
#          Avg  0.820081  0.850903  0.835964  0.867177  0.860797
#          Std  0.006392  0.003050  0.005463  0.004702  0.005505
# ROC_AUC  1    0.853297  0.904781  0.890891  0.925431  0.920480
#          2    0.859908  0.899928  0.896021  0.927934  0.922998
#          3    0.853332  0.892529  0.879640  0.920524  0.914372
#          4    0.847914  0.895996  0.889495  0.922584  0.915527
#          5    0.846360  0.901990  0.888864  0.920581  0.917421
#          Avg  0.852162  0.899045  0.888982  0.923411  0.918160
#          Std  0.005347  0.004850  0.005931  0.003223  0.003557
# F1       1    0.735856  0.783896  0.742322  0.818069  0.813256
#          2    0.727383  0.778905  0.730727  0.819192  0.808213
#          3    0.733195  0.777851  0.734871  0.809130  0.797455
#          4    0.709586  0.768555  0.715598  0.816929  0.806095
#          5    0.714156  0.776216  0.717944  0.803172  0.794745
#          Avg  0.724035  0.777085  0.728292  0.813298  0.803953
#          Std  0.011632  0.005563  0.011339  0.006903  0.007686
# LogLoss  1    0.387788  0.327321  0.383972  0.287521  0.309189
#          2    0.381962  0.320277  0.378588  0.282428  0.304702
#          3    0.385706  0.335399  0.387843  0.294331  0.321874
#          4    0.397006  0.346337  0.382557  0.291331  0.317199
#          5    0.404067  0.329207  0.390133  0.302509  0.326807
#          Avg  0.391306  0.331708  0.384618  0.291624  0.315954
#          Std  0.009033  0.009795  0.004523  0.007538  0.009038

# %% [markdown]
# ## 5. Finalizing  & Optimizing Model

# %%
data = dfScaled.drop(['nativeCountry'],axis=1)
target= df['income']

# %%
xtr,xts,ytr,yts = train_test_split(data,target,test_size=.3,random_state=101)

# %%
smot = SMOTE(random_state=101)
X_smot,ytr = smot.fit_sample(xtr,ytr)
X_smot = pd.DataFrame(X_smot, columns=xtr.columns)

# %%
xtr,xts,ytrn,yts = train_test_split(data,target,test_size=.3,random_state=101)

# %%
# from sklearn.model_selection import GridSearchCV

# parameters = {'n_estimators' : (150,200,250),
#               'max_depth':(5,10,15)}
# xgb = XGBClassifier(random_state=101)
# dt = GridSearchCV(xgb, parameters, 
#                   scoring = ['recall','precision'],
#                   refit='precision',cv=5)
# dt.fit(X_smot, ytr)
# dt.best_estimator_

# %%
model = XGBClassifier(max_depth=10, n_estimators=250, learning_rate=0.1)

# %%
model.fit(X_smot,ytr)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=10,
#               min_child_weight=1, missing=None, n_estimators=250, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
predictTrain = model.predict(xtr)
predictTrain
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
con = pd.DataFrame(data=confusion_matrix(ytrn,predictTrain), columns=['P No','P Yes'], index=['A No', 'A Yes'])
print(con)
# Out:
#         P No  P Yes
# A No   15617    534
# A Yes    566   4790

# %%
print(classification_report(ytrn,predictTrain))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97     16151
#            1       0.90      0.89      0.90      5356
#
#     accuracy                           0.95     21507
#    macro avg       0.93      0.93      0.93     21507
# weighted avg       0.95      0.95      0.95     21507

# %%
predictTest = model.predict(xts)
predictTest
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
con = pd.DataFrame(data=confusion_matrix(yts,predictTest), columns=['P No','P Yes'], index=['A No', 'A Yes'])
print(con)
# Out:
#        P No  P Yes
# A No   6305    619
# A Yes   686   1608

# %%
print(classification_report(yts,predictTest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91      6924
#            1       0.72      0.70      0.71      2294
#
#     accuracy                           0.86      9218
#    macro avg       0.81      0.81      0.81      9218
# weighted avg       0.86      0.86      0.86      9218

# %%
predictProbaTrain=model.predict_proba(xtr)

# %%
pred = predictProbaTrain[:,1]
fpr, tpr, threshold = roc_curve(ytrn, pred)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characterisitc')
plt.plot(fpr, tpr, 'b', label='AUC = {}'.format(round(roc_auc,2)))
plt.legend(loc = 'lower right')
plt.plot([0,1], [0,1], 'r--')
# plt.xlim([0,1])
# plt.ylim([0,1])
plt.ylabel('True Positive rate')
plt.xlabel('False Positive rate')
plt.show()

# %%
log_loss(ytrn,pred)
# Out:
# 0.15512186616566806

# %%
predictProbaTest=model.predict_proba(xts)

# %%
preds = predictProbaTest[:,1]
fpr, tpr, threshold = roc_curve(yts, preds)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characterisitc')
plt.plot(fpr, tpr, 'b', label='AUC = {}'.format(round(roc_auc,2)))b
plt.legend(loc = 'lower right')
plt.plot([0,1], [0,1], 'r--')
# plt.xlim([0,1])
# plt.ylim([0,1])
plt.ylabel('True Positive rate')
plt.xlabel('False Positive rate')
plt.show()

# %%
log_loss(yts,preds)
# Out:
# 0.3063744772187384

# %%
coef1 = pd.Series(model.feature_importances_,data.columns).sort_values(ascending=False)
coef1.plot(kind='bar', title='Feature Importances')

# %%
with open('XGB.pickle', 'wb') as f:
    pickle.dump(model, f)

# %% [markdown]
# ## 6. Conclusion & Business Orientation

# %% [markdown]
# <img src="https://i1.wp.com/cdn.cleverism.com/wp-content/uploads/2014/08/4Ps-marketing-mix.png?resize=451%2C433&ssl=1?resize=451x432" style="width:250px;height:250px;"/>

# %% [markdown]
# Berdasarkan Model Machine Learning yang saya buat dan di implementasikan melalui Marketing Mix Concept seperti gambar diatas, maka kesimpulannya :
#
# 1. **Place** : Model saya tidak begitu cocok untuk konsep ini, karena saya sadari bahwa untuk menentukan suatu area, data yang saya gunakan mayoritas ke negara United-States sehingga, behaviour untuk penduduk di negara tersebut dengan behaviour di negara lain akan menunjukkan pola berbeda dan akan cenderung ke negara United-States
# 2. **Product** : Untuk konsep place akan membantu ketika memakai machine learning ini, karena dari machine learning ini kita bisa menentukan target mana yang akan kita kenalkan oleh product kita, bila mereka high income maka akan dikenalkan oleh product premium, begitu juga ketika terlihat target low income maka akan dikenalkan product-product yang cocok untuk masyarakat dengan low-income
# 3. **Price** : Konsep price sendiri akan juga bisa terpengaruhi setelah kita bisa menentukan product apa yang akan kita kenalkan sesuai dengan target yang telah kita ketahui
# 4. **Promotion** : Tentu saja, promosi juga terpengaruh untuk product dengan target high-income kita bisa memiirkan konsep promosi yang sesuai dengan kelasnya.

# %% [markdown]
# #### 6.1 Comparing Class Income

# %% [markdown]
# Ketika ingin menebak target secara tepat supaya tidak membuang cost untuk melakukan promotion atau memproduksi sebuah produk, maka kita bisa memainkan threshold dari model machine learning yang saya buat

# %%
predictProbaTest=model.predict_proba(xts)

# %%
preds = predictProbaTest[:,1]
fpr, tpr, threshold = roc_curve(yts, preds)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characterisitc')
plt.plot(fpr, tpr, 'b', label='AUC = {}'.format(round(roc_auc,2)))
plt.legend(loc = 'lower right')
plt.plot([0,1], [0,1], 'r--')
# plt.xlim([0,1])
# plt.ylim([0,1])
plt.ylabel('True Positive rate')
plt.xlabel('False Positive rate')
plt.show()

# %%
print('FPR:',fpr[-760:-750])
print('TPR:',tpr[-760:-750])
print('THRESHOLD:',threshold[-760:-750])
# Out:
# FPR: [0.14428076 0.14485846 0.14485846 0.14500289 0.14500289 0.14529174
#  0.14529174 0.14630272 0.14630272 0.14673599]
# TPR: [0.79555362 0.79555362 0.79642546 0.79642546 0.79686138 0.79686138
#  0.79816914 0.79816914 0.79904098 0.79904098]
# THRESHOLD: [0.35349962 0.35295174 0.35264477 0.35222238 0.35209084 0.35191977
#  0.35132048 0.35014346 0.34985974 0.34933385]

# %%
listProba = []
for x,y,z in zip(tpr,fpr,threshold):
    listProba.append([x,y,z])
dfProba = pd.DataFrame(listProba, columns=['TPR','FPR','Threshold'])
dfProba.head()
# Out:
#         TPR  FPR  Threshold
# 0  0.000000  0.0   1.999977
# 1  0.000436  0.0   0.999977
# 2  0.004795  0.0   0.999939
# 3  0.005667  0.0   0.999936
# 4  0.012642  0.0   0.999910

# %% [markdown]
# #### 6.1.1 High Income Target

# %% [markdown]
# Karena Target untuk High Income yang dimana berarti hasil tebakan kategori 1 harus lebih tepat, maka saya akan menaikkan recall di kategori 1 (>50K)

# %%
dfProba[dfProba['TPR']>0.17].head(20)
# Out:
#          TPR       FPR  Threshold
# 20  0.190933  0.000000   0.996206
# 21  0.190933  0.000144   0.996199
# 22  0.193548  0.000144   0.995972
# 23  0.193548  0.000289   0.995946
# 24  0.235397  0.000289   0.988093
# 25  0.235397  0.000433   0.988030
# 26  0.242807  0.000433   0.984526
# 27  0.242807  0.000578   0.984437
# 28  0.248038  0.000578   0.981554
# 29  0.248038  0.000722   0.981449
# 30  0.251526  0.000722   0.978316
# 31  0.251526  0.000867   0.978031
# 32  0.253269  0.000867   0.977368
# 33  0.253269  0.001011   0.977258
# 34  0.271578  0.001011   0.960762
# 35  0.271578  0.001155   0.960659
# 36  0.272886  0.001155   0.958971
# 37  0.272886  0.001300   0.958284
# 38  0.280296  0.001300   0.950879
# 39  0.280296  0.001444   0.950775

# %%
predictions = [1 if i > 0.16 else 0 for i in preds]

# %%
print(classification_report(yts,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.74      0.84      6924
#            1       0.54      0.92      0.68      2294
#
#     accuracy                           0.79      9218
#    macro avg       0.75      0.83      0.76      9218
# weighted avg       0.86      0.79      0.80      9218

# %%
sns.countplot(predictions)

# %%
sns.countplot(yts)

# %% [markdown]
# #### 6.1.2 Low Income Target

# %% [markdown]
# Karena Target untuk High Income yang dimana berarti hasil tebakan kategori 0 harus lebih tepat, maka saya akan menaikkan recall di kategori 0 (<=50K)

# %%
dfProba[dfProba['FPR']<0.014].tail(50)
# Out:
#           TPR       FPR  Threshold
# 129  0.358762  0.009388   0.871867
# 130  0.359198  0.009388   0.871438
# 131  0.359198  0.009532   0.870440
# 132  0.360506  0.009532   0.869878
# 133  0.360506  0.009676   0.869789
# 134  0.361813  0.009676   0.869281
# 135  0.361813  0.009821   0.869098
# 136  0.364865  0.009821   0.866954
# 137  0.364865  0.009965   0.866763
# 138  0.366173  0.009965   0.864943
# 139  0.366173  0.010110   0.864878
# 140  0.367480  0.010110   0.864576
# 141  0.367480  0.010254   0.864277
# 142  0.370532  0.010254   0.862186
# 143  0.370532  0.010543   0.862154
# 144  0.372276  0.010543   0.861979
# 145  0.372276  0.010687   0.861937
# 146  0.372711  0.010687   0.861888
# 147  0.372711  0.010976   0.861180
# 148  0.375327  0.010976   0.859957
# 149  0.375327  0.011121   0.859883
# 150  0.379250  0.011121   0.856961
# 151  0.379250  0.011265   0.856819
# 152  0.381866  0.011265   0.855939
# 153  0.381866  0.011410   0.855910
# 154  0.383173  0.011410   0.855485
# 155  0.383173  0.011554   0.855417
# 156  0.384481  0.011554   0.854593
# 157  0.384481  0.011698   0.854474
# 158  0.387969  0.011698   0.850962
# 159  0.387969  0.011843   0.850851
# 160  0.391892  0.011843   0.848138
# 161  0.391892  0.011987   0.847911
# 162  0.392764  0.011987   0.847413
# 163  0.392764  0.012276   0.846450
# 164  0.394943  0.012276   0.844604
# 165  0.394943  0.012709   0.843630
# 166  0.396687  0.012709   0.843147
# 167  0.396687  0.012854   0.842491
# 168  0.397559  0.012854   0.841792
# 169  0.397559  0.013287   0.840953
# 170  0.400174  0.013287   0.838481
# 171  0.400174  0.013432   0.838397
# 172  0.401918  0.013432   0.837066
# 173  0.401918  0.013576   0.836697
# 174  0.402354  0.013576   0.836666
# 175  0.402354  0.013720   0.836238
# 176  0.403662  0.013720   0.835479
# 177  0.403662  0.013865   0.835363
# 178  0.404534  0.013865   0.834616

# %%
predictions = [1 if i > 0.78 else 0 for i in preds]

# %%
print(classification_report(yts,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91      6924
#            1       0.88      0.46      0.61      2294
#
#     accuracy                           0.85      9218
#    macro avg       0.86      0.72      0.76      9218
# weighted avg       0.85      0.85      0.83      9218

# %%
sns.countplot(predictions)

# %%
sns.countplot(yts)

# %% [markdown]
# # Terima Kasih !
